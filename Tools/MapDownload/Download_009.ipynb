# %% [markdown]
# Downloading Data:
# =================
#
# - Client ID: sh-d89408a3-f5db-4c8b-a39d-929f9f299aa9
# - Client secret: BqJ60XbDC85suN5gVlqYy6JjmJ5nwdT5
#
# Links:
# - https://documentation.dataspace.copernicus.eu/APIs/SentinelHub/Process/Examples/S2L2A.html#true-color
# - https://documentation.dataspace.copernicus.eu/notebook-samples/sentinelhub/cloudless_process_api.html

# %%
# Print basic timestamp and python version information

import time
import sys

print("Timestamp: ", time.strftime("%Y-%m-%d %H:%M:%S"))
print("Python version: ", sys.version)
# Out:
# Timestamp:  2025-02-04 12:41:43
# Python version:  3.12.5 (tags/v3.12.5:ff3bc82, Aug  6 2024, 20:45:27) [MSC v.1940 64 bit (AMD64)]

# %%
# Update pip itself
# !pip install --upgrade pip

# Setup the environment with pip installs and imports
installs = ["sentinelhub", "numpy", "pandas", "matplotlib", "requests", "getpass", "scipy"]
for package in installs:
    # !pip install {package}
# Out:
# Requirement already satisfied: pip in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (25.0)
# Requirement already satisfied: sentinelhub in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (3.11.1)
# Requirement already satisfied: aenum>=2.1.4 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (3.1.15)
# Requirement already satisfied: click in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (8.1.7)
# Requirement already satisfied: dataclasses-json in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (0.6.7)
# Requirement already satisfied: numpy in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (2.1.0)
# Requirement already satisfied: oauthlib in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (3.2.2)
# Requirement already satisfied: pillow>=9.2.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (10.4.0)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (3.7.0)
# Requirement already satisfied: python-dateutil in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from sentinelhub) (2.9.0.post0)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (2.0.0)
# Requirement already satisfied: requests>=2.27.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (2.32.3)
# Requirement already satisfied: shapely in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (2.0.6)
# Requirement already satisfied: tifffile>=2020.9.30 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (2024.9.20)
# Requirement already satisfied: tomli in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (2.2.1)
# Requirement already satisfied: tomli-w in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (4.12.2)
# Requirement already satisfied: utm in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from sentinelhub) (0.7.0)
# Requirement already satisfied: certifi in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from pyproj>=2.2.0->sentinelhub) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27.0->sentinelhub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27.0->sentinelhub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27.0->sentinelhub) (2.2.3)
# Requirement already satisfied: colorama in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from click->sentinelhub) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->sentinelhub) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->sentinelhub) (0.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from python-dateutil->sentinelhub) (1.16.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->sentinelhub) (24.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->sentinelhub) (1.0.0)
# Requirement already satisfied: numpy in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (2.1.0)
# Requirement already satisfied: pandas in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\steadmand\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: requests in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.8.30)
# ERROR: Could not find a version that satisfies the requirement getpass (from versions: none)
# ERROR: No matching distribution found for getpass
# Requirement already satisfied: scipy in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (1.15.1)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\steadmand\appdata\local\programs\python\python312\lib\site-packages (from scipy) (2.1.0)

# %%
# Utilities
import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
import getpass

from sentinelhub import (
    SHConfig,
    DataCollection,
    SentinelHubCatalog,
    SentinelHubRequest,
    BBox,
    bbox_to_dimensions,
    CRS,
    MimeType,
    Geometry,
)

# %%
# Your client credentials
#Client ID: sh-d89408a3-f5db-4c8b-a39d-929f9f299aa9
#Client secret: BqJ60XbDC85suN5gVlqYy6JjmJ5nwdT5
client_id = 'sh-d89408a3-f5db-4c8b-a39d-929f9f299aa9'
client_secret = 'BqJ60XbDC85suN5gVlqYy6JjmJ5nwdT5'

# %%
from oauthlib.oauth2 import BackendApplicationClient
from requests_oauthlib import OAuth2Session

def SetupOAuth(client_id, client_secret):

    # Create a session
    client = BackendApplicationClient(client_id=client_id)
    oauth = OAuth2Session(client=client)

    # Get token for the session
    token = oauth.fetch_token(token_url='https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token',
                            client_secret=client_secret, include_client_id=True)

    # All requests using this session will have an access token automatically added
    resp = oauth.get("https://sh.dataspace.copernicus.eu/configuration/v1/wms/instances")

    return oauth

oauth = SetupOAuth(client_id, client_secret)

# %%
# Create strings to support the query

def CreateBBoxString(minlon, minlat, maxlon, maxlat):
    return f"[{minlon}, {minlat}, {maxlon}, {maxlat}]"

def CreateTimerangeString(date):
    # add buffer around the stated date
    datespace = datetime.timedelta(days=2)
    startdate = date - datespace
    enddate = date + datespace

    # format individual date strings
    from_date = f"{startdate.strftime('%Y-%m-%d')}T00:00:00Z"
    to_date = f"{enddate.strftime('%Y-%m-%d')}T23:59:59Z"

    # return the collated/formatted answer
    return {"from": from_date, "to": to_date}

# %%
from PIL import Image
from io import BytesIO


def download_GM(outpath, bl_lat, bl_lon, width):

    minlat = bl_lat
    maxlat = bl_lat + width
    minlon = bl_lon
    maxlon = bl_lon + width

    evalscript_GM = """
    //VERSION=3
    function setup() {
        return {
            input: ["B02", "B03", "B04"],
            output: { bands: 3 }
        };
    }

    function evaluatePixel(sample) {
        return [3.5 * sample.B04/10000, 3.5 * sample.B03/10000, 3.5 * sample.B02/10000];
    }
    """

    request_GM = {
    "input": {
        "bounds": {
        "bbox": [minlon, minlat, maxlon, maxlat]
        },
        "data": [
        {
            "dataFilter": {
            "timeRange": {
                "from": "2023-07-01T00:00:00Z",
                "to": "2023-07-01T23:59:59Z"
            }
            },
            "type": "byoc-5460de54-082e-473a-b6ea-d5cbe3c17cca"

        }
        ]
    },
    "output": {
        "width": 1024,
        "height": 1024,
        "responses": [
        {
            "identifier": "default",
            "format": {
                "type": "image/png"
            }
        }
        ]
    },
    "evalscript": evalscript_GM,
    }

    url = "https://sh.dataspace.copernicus.eu/api/v1/process"
    response = oauth.post(url, json=request_GM)

    # Output the result to a file
    if response.status_code == 200:
        image = Image.open(BytesIO(response.content))
        image.save(outpath)
    else:
        print(f"Request failed with status code {response.status_code}")

# %%
globalmosaic_dates = {
    "2023Q1": "2023-01-01",
    "2023Q2": "2023-04-01",
    "2023Q3": "2023-07-01",
    "2023Q4": "2023-10-01",
    "2024Q1": "2024-01-01",
    "2024Q2": "2024-04-01",
    "2024Q3": "2024-07-01",
}

# %%
from PIL import Image
from io import BytesIO


def download_GM2(outpath, datestr, bl_lat, bl_lon, width):

    oauth = SetupOAuth(client_id, client_secret)

    minlat = bl_lat
    maxlat = bl_lat + width
    minlon = bl_lon
    maxlon = bl_lon + width

    # datestr = "2023-07-01"
    fromstr = f"{datestr}T00:00:00Z"
    tostr   = f"{datestr}T23:59:59Z"

    evalscript_GM = """
    //VERSION=3
    function setup() {
        return {
            input: ["B02", "B03", "B04"],
            output: { bands: 3 }
        };
    }

    function evaluatePixel(sample) {
        return [3.5 * sample.B04/10000, 3.5 * sample.B03/10000, 3.5 * sample.B02/10000];
    }
    """

    request_GM = {
    "input": {
        "bounds": {
        "bbox": [minlon, minlat, maxlon, maxlat]
        },
        "data": [
        {
            "dataFilter": {
            "timeRange": {
                "from": fromstr,
                "to": tostr
            }
            },
            "type": "byoc-5460de54-082e-473a-b6ea-d5cbe3c17cca"

        }
        ]
    },
    "output": {
        "width": 1024,
        "height": 1024,
        "responses": [
        {
            "identifier": "default",
            "format": {
                "type": "image/png"
            }
        }
        ]
    },
    "evalscript": evalscript_GM,
    }

    url = "https://sh.dataspace.copernicus.eu/api/v1/process"
    response = oauth.post(url, json=request_GM)

    # Output the result to a file
    if response.status_code == 200:
        image = Image.open(BytesIO(response.content))
        image.save(outpath)
    else:
        print(f"Request failed with status code {response.status_code}")

# %%
import os

# function to make sure a path exists. If not, create it
def ensure_dir(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
# Data structure for the metadata
image_data_5Deg = [
    {"filename": "Sat_EL_DD.png", "lat": -50, "long": 165, "width": 5},
    {"filename": "Sat_EL_CD.png", "lat": -45, "long": 165, "width": 5},
    {"filename": "Sat_EL_DE.png", "lat": -50, "long": 170, "width": 5},
]

image_data_1Deg = [
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_CC.png", "lat": -48, "long": 167, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_CD.png", "lat": -48, "long": 168, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_BB.png", "lat": -47, "long": 166, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_BC.png", "lat": -47, "long": 167, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_BD.png", "lat": -47, "long": 168, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_BE.png", "lat": -47, "long": 169, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_AB.png", "lat": -46, "long": 166, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_AC.png", "lat": -46, "long": 167, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_AD.png", "lat": -46, "long": 168, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DD/", "filename": "Sat_EL_DD_AE.png", "lat": -46, "long": 169, "width": 1},

    {"localpath": "Lvl2_1x1/EL_CD/", "filename": "Sat_EL_CD_EC.png", "lat": -45, "long": 167, "width": 1},
    {"localpath": "Lvl2_1x1/EL_CD/", "filename": "Sat_EL_CD_ED.png", "lat": -45, "long": 168, "width": 1},
    {"localpath": "Lvl2_1x1/EL_CD/", "filename": "Sat_EL_CD_EE.png", "lat": -45, "long": 169, "width": 1},
    {"localpath": "Lvl2_1x1/EL_CD/", "filename": "Sat_EL_CD_DC.png", "lat": -44, "long": 167, "width": 1},
    {"localpath": "Lvl2_1x1/EL_CD/", "filename": "Sat_EL_CD_DD.png", "lat": -44, "long": 168, "width": 1},
    {"localpath": "Lvl2_1x1/EL_CD/", "filename": "Sat_EL_CD_DE.png", "lat": -44, "long": 169, "width": 1},

    {"localpath": "Lvl2_1x1/EL_DE/", "filename": "Sat_EL_DE_AA.png", "lat": -46, "long": 170, "width": 1},
    {"localpath": "Lvl2_1x1/EL_DE/", "filename": "Sat_EL_DE_BA.png", "lat": -47, "long": 170, "width": 1},
]


iceland_data_1Deg = [
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_BC.png", "lat": 63, "long": -23, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_BD.png", "lat": 63, "long": -22, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_BE.png", "lat": 63, "long": -21, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_AA.png", "lat": 64, "long": -25, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_AB.png", "lat": 64, "long": -24, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_AC.png", "lat": 64, "long": -23, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_AD.png", "lat": 64, "long": -22, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FB/", "filename": "Sat_AF_FB_AE.png", "lat": 64, "long": -21, "width": 1},

    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_EA.png", "lat": 65, "long": -25, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_EB.png", "lat": 65, "long": -24, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_EC.png", "lat": 65, "long": -23, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_ED.png", "lat": 65, "long": -22, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_EE.png", "lat": 65, "long": -21, "width": 1},

    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_DA.png", "lat": 66, "long": -25, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_DB.png", "lat": 66, "long": -24, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_DC.png", "lat": 66, "long": -23, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_DD.png", "lat": 66, "long": -22, "width": 1},
    {"localpath": "Lvl2_1x1/AF_EB/", "filename": "Sat_AF_EB_DE.png", "lat": 66, "long": -21, "width": 1},

    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_AA.png", "lat": 64, "long": -20, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_AB.png", "lat": 64, "long": -19, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_AC.png", "lat": 64, "long": -18, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_AD.png", "lat": 64, "long": -17, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_AE.png", "lat": 64, "long": -16, "width": 1},

    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_BA.png", "lat": 63, "long": -20, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_BB.png", "lat": 63, "long": -19, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_BC.png", "lat": 63, "long": -18, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_BD.png", "lat": 63, "long": -17, "width": 1},
    {"localpath": "Lvl2_1x1/AF_FC/", "filename": "Sat_AF_FC_BE.png", "lat": 63, "long": -16, "width": 1},


]

# %%
australia_data_5Deg = [
    {"localpath": "Lvl1_5x5/DJ/", "filename": "Sat_DJ_DE.png", "lat": -20, "long": 110, "width": 5},
    {"localpath": "Lvl1_5x5/DJ/", "filename": "Sat_DJ_DF.png", "lat": -20, "long": 115, "width": 5},

    {"localpath": "Lvl1_5x5/DJ/", "filename": "Sat_DJ_EE.png", "lat": -25, "long": 110, "width": 5},
    {"localpath": "Lvl1_5x5/DJ/", "filename": "Sat_DJ_EF.png", "lat": -25, "long": 115, "width": 5},

    {"localpath": "Lvl1_5x5/DJ/", "filename": "Sat_DJ_FE.png", "lat": -30, "long": 110, "width": 5},
    {"localpath": "Lvl1_5x5/DJ/", "filename": "Sat_DJ_FF.png", "lat": -30, "long": 115, "width": 5},


    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_BA.png", "lat": -10, "long": 120, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_BB.png", "lat": -10, "long": 125, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_BC.png", "lat": -10, "long": 130, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_BD.png", "lat": -10, "long": 135, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_BE.png", "lat": -10, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_BF.png", "lat": -10, "long": 145, "width": 5},

    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_CA.png", "lat": -15, "long": 120, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_CB.png", "lat": -15, "long": 125, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_CC.png", "lat": -15, "long": 130, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_CD.png", "lat": -15, "long": 135, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_CE.png", "lat": -15, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_CF.png", "lat": -15, "long": 145, "width": 5},

    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_DA.png", "lat": -20, "long": 120, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_DB.png", "lat": -20, "long": 125, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_DC.png", "lat": -20, "long": 130, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_DD.png", "lat": -20, "long": 135, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_DE.png", "lat": -20, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_DF.png", "lat": -20, "long": 145, "width": 5},

    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_EA.png", "lat": -25, "long": 120, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_EB.png", "lat": -25, "long": 125, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_EC.png", "lat": -25, "long": 130, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_ED.png", "lat": -25, "long": 135, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_EE.png", "lat": -25, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_EF.png", "lat": -25, "long": 145, "width": 5},

    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_FA.png", "lat": -30, "long": 120, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_FB.png", "lat": -30, "long": 125, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_FC.png", "lat": -30, "long": 130, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_FD.png", "lat": -30, "long": 135, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_FE.png", "lat": -30, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/DK/", "filename": "Sat_DK_FF.png", "lat": -30, "long": 145, "width": 5},


    {"localpath": "Lvl1_5x5/DL/", "filename": "Sat_DL_EA.png", "lat": -25, "long": 150, "width": 5},
    {"localpath": "Lvl1_5x5/DL/", "filename": "Sat_DL_FA.png", "lat": -30, "long": 150, "width": 5},

    {"localpath": "Lvl1_5x5/EJ/", "filename": "Sat_EJ_AE.png", "lat": -35, "long": 110, "width": 5},
    {"localpath": "Lvl1_5x5/EJ/", "filename": "Sat_EJ_AF.png", "lat": -35, "long": 115, "width": 5},

    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_AA.png", "lat": -35, "long": 120, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_AB.png", "lat": -35, "long": 125, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_AC.png", "lat": -35, "long": 130, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_AD.png", "lat": -35, "long": 135, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_AE.png", "lat": -35, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_AF.png", "lat": -35, "long": 145, "width": 5},

    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_BD.png", "lat": -40, "long": 135, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_BE.png", "lat": -40, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_BF.png", "lat": -40, "long": 145, "width": 5},

    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_CE.png", "lat": -45, "long": 140, "width": 5},
    {"localpath": "Lvl1_5x5/EK/", "filename": "Sat_EK_CF.png", "lat": -45, "long": 145, "width": 5},


    {"localpath": "Lvl1_5x5/EL/", "filename": "Sat_EL_AA.png", "lat": -35, "long": 150, "width": 5},
    {"localpath": "Lvl1_5x5/EL/", "filename": "Sat_EL_BA.png", "lat": -40, "long": 150, "width": 5},


]

# %%
iberia_data_5Deg = [
    {"localpath": "Lvl1_5x5/BF/", "filename": "Sat_BF_DE.png", "lat": 40, "long": -10, "width": 5},
    {"localpath": "Lvl1_5x5/BF/", "filename": "Sat_BF_DF.png", "lat": 40, "long":  -5, "width": 5},
    {"localpath": "Lvl1_5x5/BF/", "filename": "Sat_BF_EE.png", "lat": 35, "long": -10, "width": 5},
    {"localpath": "Lvl1_5x5/BF/", "filename": "Sat_BF_EF.png", "lat": 35, "long":  -5, "width": 5},
]

iberia_data_1Deg = [
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_AA.png", "lat": 44, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_AB.png", "lat": 44, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_AC.png", "lat": 44, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_AD.png", "lat": 44, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_AE.png", "lat": 44, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_BA.png", "lat": 43, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_BB.png", "lat": 43, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_BC.png", "lat": 43, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_BD.png", "lat": 43, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_BE.png", "lat": 43, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_CA.png", "lat": 42, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_CB.png", "lat": 42, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_CC.png", "lat": 42, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_CD.png", "lat": 42, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_CE.png", "lat": 42, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_DA.png", "lat": 41, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_DB.png", "lat": 41, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_DC.png", "lat": 41, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_DD.png", "lat": 41, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_DE.png", "lat": 41, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_EA.png", "lat": 40, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_EB.png", "lat": 40, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_EC.png", "lat": 40, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_ED.png", "lat": 40, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DE/", "filename": "Sat_BF_DE_EE.png", "lat": 40, "long":  -6, "width": 1},



    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_AA.png", "lat": 44, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_AB.png", "lat": 44, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_AC.png", "lat": 44, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_AD.png", "lat": 44, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_AE.png", "lat": 44, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_BA.png", "lat": 43, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_BB.png", "lat": 43, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_BC.png", "lat": 43, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_BD.png", "lat": 43, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_BE.png", "lat": 43, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_CA.png", "lat": 42, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_CB.png", "lat": 42, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_CC.png", "lat": 42, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_CD.png", "lat": 42, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_CE.png", "lat": 42, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_DA.png", "lat": 41, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_DB.png", "lat": 41, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_DC.png", "lat": 41, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_DD.png", "lat": 41, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_DE.png", "lat": 41, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_EA.png", "lat": 40, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_EB.png", "lat": 40, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_EC.png", "lat": 40, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_ED.png", "lat": 40, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_DF/", "filename": "Sat_BF_DF_EE.png", "lat": 40, "long":  -1, "width": 1},



    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_AA.png", "lat": 39, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_AB.png", "lat": 39, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_AC.png", "lat": 39, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_AD.png", "lat": 39, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_AE.png", "lat": 39, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_BA.png", "lat": 38, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_BB.png", "lat": 38, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_BC.png", "lat": 38, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_BD.png", "lat": 38, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_BE.png", "lat": 38, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_CA.png", "lat": 37, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_CB.png", "lat": 37, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_CC.png", "lat": 37, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_CD.png", "lat": 37, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_CE.png", "lat": 37, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_DA.png", "lat": 36, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_DB.png", "lat": 36, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_DC.png", "lat": 36, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_DD.png", "lat": 36, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_DE.png", "lat": 36, "long":  -6, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_EA.png", "lat": 35, "long": -10, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_EB.png", "lat": 35, "long":  -9, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_EC.png", "lat": 35, "long":  -8, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_ED.png", "lat": 35, "long":  -7, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EE/", "filename": "Sat_BF_EE_EE.png", "lat": 35, "long":  -6, "width": 1},



    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_AA.png", "lat": 39, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_AB.png", "lat": 39, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_AC.png", "lat": 39, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_AD.png", "lat": 39, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_AE.png", "lat": 39, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_BA.png", "lat": 38, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_BB.png", "lat": 38, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_BC.png", "lat": 38, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_BD.png", "lat": 38, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_BE.png", "lat": 38, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_CA.png", "lat": 37, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_CB.png", "lat": 37, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_CC.png", "lat": 37, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_CD.png", "lat": 37, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_CE.png", "lat": 37, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_DA.png", "lat": 36, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_DB.png", "lat": 36, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_DC.png", "lat": 36, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_DD.png", "lat": 36, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_DE.png", "lat": 36, "long":  -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_EA.png", "lat": 35, "long":  -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_EB.png", "lat": 35, "long":  -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_EC.png", "lat": 35, "long":  -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_ED.png", "lat": 35, "long":  -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_EF/", "filename": "Sat_BF_EF_EE.png", "lat": 35, "long":  -1, "width": 1},

]

# %%
westmed_data_5Deg = [
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_DA.png", "lat": 40, "long":   0, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_DB.png", "lat": 40, "long":   5, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_EA.png", "lat": 35, "long":   0, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_EB.png", "lat": 35, "long":   5, "width": 5},
]

westmed_data_1Deg = [
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_AA.png", "lat": 44, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_AB.png", "lat": 44, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_AC.png", "lat": 44, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_AD.png", "lat": 44, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_AE.png", "lat": 44, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_BA.png", "lat": 43, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_BB.png", "lat": 43, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_BC.png", "lat": 43, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_BD.png", "lat": 43, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_BE.png", "lat": 43, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_CA.png", "lat": 42, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_CB.png", "lat": 42, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_CC.png", "lat": 42, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_CD.png", "lat": 42, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_CE.png", "lat": 42, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_DA.png", "lat": 41, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_DB.png", "lat": 41, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_DC.png", "lat": 41, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_DD.png", "lat": 41, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_DE.png", "lat": 41, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_EA.png", "lat": 40, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_EB.png", "lat": 40, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_EC.png", "lat": 40, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_ED.png", "lat": 40, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_DA/", "filename": "Sat_BG_DA_EE.png", "lat": 40, "long": 4, "width": 1},

]

# %%
france_data_5Deg = [
    {"localpath": "Lvl1_5x5/BF/", "filename": "Sat_BF_CF.png", "lat": 45, "long": -5, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_CA.png", "lat": 45, "long":  0, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_CB.png", "lat": 45, "long":  5, "width": 5},
]


france_data_1Deg = [
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_AA.png", "lat": 49, "long": -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_AB.png", "lat": 49, "long": -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_AC.png", "lat": 49, "long": -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_AD.png", "lat": 49, "long": -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_AE.png", "lat": 49, "long": -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_BA.png", "lat": 48, "long": -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_BB.png", "lat": 48, "long": -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_BC.png", "lat": 48, "long": -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_BD.png", "lat": 48, "long": -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_BE.png", "lat": 48, "long": -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_CA.png", "lat": 47, "long": -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_CB.png", "lat": 47, "long": -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_CC.png", "lat": 47, "long": -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_CD.png", "lat": 47, "long": -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_CE.png", "lat": 47, "long": -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_DA.png", "lat": 46, "long": -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_DB.png", "lat": 46, "long": -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_DC.png", "lat": 46, "long": -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_DD.png", "lat": 46, "long": -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_DE.png", "lat": 46, "long": -1, "width": 1},

    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_EA.png", "lat": 45, "long": -5, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_EB.png", "lat": 45, "long": -4, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_EC.png", "lat": 45, "long": -3, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_ED.png", "lat": 45, "long": -2, "width": 1},
    {"localpath": "Lvl2_1x1/BF_CF/", "filename": "Sat_BF_CF_EE.png", "lat": 45, "long": -1, "width": 1},



    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_AA.png", "lat": 49, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_AB.png", "lat": 49, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_AC.png", "lat": 49, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_AD.png", "lat": 49, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_AE.png", "lat": 49, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_BA.png", "lat": 48, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_BB.png", "lat": 48, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_BC.png", "lat": 48, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_BD.png", "lat": 48, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_BE.png", "lat": 48, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_CA.png", "lat": 47, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_CB.png", "lat": 47, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_CC.png", "lat": 47, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_CD.png", "lat": 47, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_CE.png", "lat": 47, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_DA.png", "lat": 46, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_DB.png", "lat": 46, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_DC.png", "lat": 46, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_DD.png", "lat": 46, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_DE.png", "lat": 46, "long": 4, "width": 1},

    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_EA.png", "lat": 45, "long": 0, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_EB.png", "lat": 45, "long": 1, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_EC.png", "lat": 45, "long": 2, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_ED.png", "lat": 45, "long": 3, "width": 1},
    {"localpath": "Lvl2_1x1/BG_CA/", "filename": "Sat_BG_CA_EE.png", "lat": 45, "long": 4, "width": 1},


]

# %%
belgium_data_5Deg = [
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_BA.png", "lat": 50, "long": 0, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_BB.png", "lat": 50, "long": 5, "width": 5},
]


centralmed_data_5deg = [
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_DC.png", "lat": 40, "long": 10, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_DD.png", "lat": 40, "long": 15, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_DE.png", "lat": 40, "long": 20, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_DF.png", "lat": 40, "long": 25, "width": 5},

    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_EC.png", "lat": 35, "long": 10, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_ED.png", "lat": 35, "long": 15, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_EE.png", "lat": 35, "long": 20, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_EF.png", "lat": 35, "long": 25, "width": 5},

    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_FC.png", "lat": 30, "long": 10, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_FD.png", "lat": 30, "long": 15, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_FE.png", "lat": 30, "long": 20, "width": 5},
    {"localpath": "Lvl1_5x5/BG/", "filename": "Sat_BG_FF.png", "lat": 30, "long": 25, "width": 5},
]

# %%
def create_1deg_dictionary(path, filenamestart, startlat, startlong):
    dictionary = {}

    # Loop over 5 lats
    for currlatid in range(5):
        currlatletter = chr(ord('A') + currlatid)  # Get letter A-E for lat
        currlat = startlat + (4 - currlatid)

        # Loop over 5 longs
        for currlongid in range(5):
            currlongletter = chr(ord('A') + currlongid)  # Get letter A-E for long
            currlong = startlong + currlongid

            # Generate the filename based on letters
            currfilename = f"{filenamestart}{currlatletter}{currlongletter}.png"

            # Create dictionary entry
            dictionary[currfilename] = {
                "localpath": path,
                "filename": currfilename,
                "lat": currlat,
                "long": currlong,
                "width": 1  # Assuming each 1-degree tile has a width of 1
            }

    return dictionary

# %%
temp_data = create_1deg_dictionary("Lvl2_1x1/BG_BA/", "Sat_BG_BA_", 54, 0)

# print temp_data verbose/formatted
for key, value in temp_data.items():
    print(f"\"{key}\": {value},")
# Out:
# "Sat_BG_BA_AA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AA.png', 'lat': 58, 'long': 0, 'width': 1},
# "Sat_BG_BA_AB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AB.png', 'lat': 58, 'long': 1, 'width': 1},
# "Sat_BG_BA_AC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AC.png', 'lat': 58, 'long': 2, 'width': 1},
# "Sat_BG_BA_AD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AD.png', 'lat': 58, 'long': 3, 'width': 1},
# "Sat_BG_BA_AE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AE.png', 'lat': 58, 'long': 4, 'width': 1},
# "Sat_BG_BA_BA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BA.png', 'lat': 57, 'long': 0, 'width': 1},
# "Sat_BG_BA_BB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BB.png', 'lat': 57, 'long': 1, 'width': 1},
# "Sat_BG_BA_BC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BC.png', 'lat': 57, 'long': 2, 'width': 1},
# "Sat_BG_BA_BD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BD.png', 'lat': 57, 'long': 3, 'width': 1},
# "Sat_BG_BA_BE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BE.png', 'lat': 57, 'long': 4, 'width': 1},
# "Sat_BG_BA_CA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CA.png', 'lat': 56, 'long': 0, 'width': 1},
# "Sat_BG_BA_CB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CB.png', 'lat': 56, 'long': 1, 'width': 1},
# "Sat_BG_BA_CC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CC.png', 'lat': 56, 'long': 2, 'width': 1},
# "Sat_BG_BA_CD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CD.png', 'lat': 56, 'long': 3, 'width': 1},
# "Sat_BG_BA_CE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CE.png', 'lat': 56, 'long': 4, 'width': 1},
# "Sat_BG_BA_DA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DA.png', 'lat': 55, 'long': 0, 'width': 1},
# "Sat_BG_BA_DB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DB.png', 'lat': 55, 'long': 1, 'width': 1},
# "Sat_BG_BA_DC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DC.png', 'lat': 55, 'long': 2, 'width': 1},
# "Sat_BG_BA_DD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DD.png', 'lat': 55, 'long': 3, 'width': 1},
# "Sat_BG_BA_DE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DE.png', 'lat': 55, 'long': 4, 'width': 1},
# "Sat_BG_BA_EA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EA.png', 'lat': 54, 'long': 0, 'width': 1},
# "Sat_BG_BA_EB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EB.png', 'lat': 54, 'long': 1, 'width': 1},
# "Sat_BG_BA_EC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EC.png', 'lat': 54, 'long': 2, 'width': 1},
# "Sat_BG_BA_ED.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_ED.png', 'lat': 54, 'long': 3, 'width': 1},
# "Sat_BG_BA_EE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EE.png', 'lat': 54, 'long': 4, 'width': 1},

# %%
def create_sub1deg_dictionary(path, filenamestart, startlat, startlong):
    dictionary = {}

    latdelta  = 0.2
    longdelta = 0.2

    # Loop over 5 lats
    for currlatid in range(5):
        currlatletter = chr(ord('A') + currlatid)  # Get letter A-E for lat
        currlat = startlat + (1 - ((currlatid + 1) * latdelta))

        # Loop over 5 longs
        for currlongid in range(5):
            currlongletter = chr(ord('A') + currlongid)  # Get letter A-E for long
            currlong = startlong + (currlongid * longdelta)

            # Generate the filename based on letters
            currfilename = f"{filenamestart}{currlatletter}{currlongletter}.png"

            # Create dictionary entry
            dictionary[currfilename] = {
                "localpath": path,
                "filename": currfilename,
                "lat": currlat,
                "long": currlong,
                "width": 0.2  # Assuming each 1-degree tile has a width of 1
            }

    return dictionary

# %%
temp_data = create_sub1deg_dictionary("Lvl2_1x1/BF_BF_CA/", "Sat_BF_BF_CA_", 52, -5)

# print temp_data verbose/formatted
for key, value in temp_data.items():
    print(f"\"{key}\": {value},")
# Out:
# "Sat_BF_BF_CA_AA.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_AA.png', 'lat': 56, 'long': -5, 'width': 1},
# "Sat_BF_BF_CA_AB.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_AB.png', 'lat': 56, 'long': -4, 'width': 1},
# "Sat_BF_BF_CA_AC.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_AC.png', 'lat': 56, 'long': -3, 'width': 1},
# "Sat_BF_BF_CA_AD.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_AD.png', 'lat': 56, 'long': -2, 'width': 1},
# "Sat_BF_BF_CA_AE.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_AE.png', 'lat': 56, 'long': -1, 'width': 1},
# "Sat_BF_BF_CA_BA.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_BA.png', 'lat': 55, 'long': -5, 'width': 1},
# "Sat_BF_BF_CA_BB.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_BB.png', 'lat': 55, 'long': -4, 'width': 1},
# "Sat_BF_BF_CA_BC.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_BC.png', 'lat': 55, 'long': -3, 'width': 1},
# "Sat_BF_BF_CA_BD.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_BD.png', 'lat': 55, 'long': -2, 'width': 1},
# "Sat_BF_BF_CA_BE.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_BE.png', 'lat': 55, 'long': -1, 'width': 1},
# "Sat_BF_BF_CA_CA.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_CA.png', 'lat': 54, 'long': -5, 'width': 1},
# "Sat_BF_BF_CA_CB.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_CB.png', 'lat': 54, 'long': -4, 'width': 1},
# "Sat_BF_BF_CA_CC.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_CC.png', 'lat': 54, 'long': -3, 'width': 1},
# "Sat_BF_BF_CA_CD.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_CD.png', 'lat': 54, 'long': -2, 'width': 1},
# "Sat_BF_BF_CA_CE.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_CE.png', 'lat': 54, 'long': -1, 'width': 1},
# "Sat_BF_BF_CA_DA.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_DA.png', 'lat': 53, 'long': -5, 'width': 1},
# "Sat_BF_BF_CA_DB.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_DB.png', 'lat': 53, 'long': -4, 'width': 1},
# "Sat_BF_BF_CA_DC.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_DC.png', 'lat': 53, 'long': -3, 'width': 1},
# "Sat_BF_BF_CA_DD.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_DD.png', 'lat': 53, 'long': -2, 'width': 1},
# "Sat_BF_BF_CA_DE.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_DE.png', 'lat': 53, 'long': -1, 'width': 1},
# "Sat_BF_BF_CA_EA.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_EA.png', 'lat': 52, 'long': -5, 'width': 1},
# "Sat_BF_BF_CA_EB.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_EB.png', 'lat': 52, 'long': -4, 'width': 1},
# "Sat_BF_BF_CA_EC.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_EC.png', 'lat': 52, 'long': -3, 'width': 1},
# "Sat_BF_BF_CA_ED.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_ED.png', 'lat': 52, 'long': -2, 'width': 1},
# "Sat_BF_BF_CA_EE.png": {'localpath': 'Lvl2_1x1/BF_BF_CA/', 'filename': 'Sat_BF_BF_CA_EE.png', 'lat': 52, 'long': -1, 'width': 1},

# %%
belgium_data_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BA/", "Sat_BG_BA_", 50, 0)

BG_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BB/", "Sat_BG_BB_", 50, 5)
BG_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CB/", "Sat_BG_CB_", 45, 5)


BG_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AB/", "Sat_BG_AB_", 55,  5)
BG_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AC/", "Sat_BG_AC_", 55, 10)
BG_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AD/", "Sat_BG_AD_", 55, 15)
BG_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AE/", "Sat_BG_AE_", 55, 20)
BG_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AF/", "Sat_BG_AF_", 55, 25)

BG_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BB/", "Sat_BG_BB_", 50,  5)
BG_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BC/", "Sat_BG_BC_", 50, 10)
BG_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BD/", "Sat_BG_BD_", 50, 15)
BG_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BE/", "Sat_BG_BE_", 50, 20)
BG_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BF/", "Sat_BG_BF_", 50, 25)

BG_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CC/", "Sat_BG_CC_", 45, 10)
BG_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CD/", "Sat_BG_CD_", 45, 15)
BG_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CE/", "Sat_BG_CE_", 45, 20)
BG_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CF/", "Sat_BG_CF_", 45, 25)



AG_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_FA/", "Sat_AG_FA_", 60,  0)
AG_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_FB/", "Sat_AG_FB_", 60,  5)
AG_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_FC/", "Sat_AG_FC_", 60, 10)
AG_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_FD/", "Sat_AG_FD_", 60, 15)
AG_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_FE/", "Sat_AG_FE_", 60, 20)
AG_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_FF/", "Sat_AG_FF_", 60, 25)

# a list of the dictionaries
list_1Degs = [
    AG_FA_1Deg,
    AG_FB_1Deg,
    AG_FC_1Deg,
    AG_FD_1Deg,
    AG_FE_1Deg,
    AG_FF_1Deg,
]


AG_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_EC/", "Sat_AG_EC_", 65, 10)
AG_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_ED/", "Sat_AG_ED_", 65, 15)
AG_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_EE/", "Sat_AG_EE_", 65, 20)
AG_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/AG_EF/", "Sat_AG_EF_", 65, 25)

# a list of the dictionaries
list_1Degs = [
    AG_EC_1Deg,
    AG_ED_1Deg,
    AG_EE_1Deg,
    AG_EF_1Deg,
]



BF_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/BF_AE/", "Sat_BF_AE_", 55, -10)
BF_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/BF_AF/", "Sat_BF_AF_", 55,  -5)
BF_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/BF_BE/", "Sat_BF_BE_", 50, -10)
BF_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/BF_BF/", "Sat_BF_BF_", 50,  -5)


list_1Degs = [
    BF_AE_1Deg,
    BF_AF_1Deg,
    BF_BE_1Deg,
    BF_BF_1Deg,
]

BG_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AA/", "Sat_BG_AA_", 55, 0)
BF_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/BF_CE/", "Sat_BF_CE_", 45, -10)
BF_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/BF_BD/", "Sat_BF_BD_", 50, -15)

AF_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/AF_FE/", "Sat_AF_FE_", 60, -10)
AF_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/AF_FF/", "Sat_AF_FF_", 60, -5)

list_1Degs = [
    BG_AA_1Deg,
    BF_CE_1Deg,
    BF_BD_1Deg,
    AF_FE_1Deg,
    AF_FF_1Deg
]



# print temp_data verbose/formatted
for key, value in belgium_data_1Deg.items():
    print(f"\"{key}\": {value},")
# Out:
# "Sat_BG_BA_AA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AA.png', 'lat': 54, 'long': 0, 'width': 1},
# "Sat_BG_BA_AB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AB.png', 'lat': 54, 'long': 1, 'width': 1},
# "Sat_BG_BA_AC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AC.png', 'lat': 54, 'long': 2, 'width': 1},
# "Sat_BG_BA_AD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AD.png', 'lat': 54, 'long': 3, 'width': 1},
# "Sat_BG_BA_AE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_AE.png', 'lat': 54, 'long': 4, 'width': 1},
# "Sat_BG_BA_BA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BA.png', 'lat': 53, 'long': 0, 'width': 1},
# "Sat_BG_BA_BB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BB.png', 'lat': 53, 'long': 1, 'width': 1},
# "Sat_BG_BA_BC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BC.png', 'lat': 53, 'long': 2, 'width': 1},
# "Sat_BG_BA_BD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BD.png', 'lat': 53, 'long': 3, 'width': 1},
# "Sat_BG_BA_BE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_BE.png', 'lat': 53, 'long': 4, 'width': 1},
# "Sat_BG_BA_CA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CA.png', 'lat': 52, 'long': 0, 'width': 1},
# "Sat_BG_BA_CB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CB.png', 'lat': 52, 'long': 1, 'width': 1},
# "Sat_BG_BA_CC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CC.png', 'lat': 52, 'long': 2, 'width': 1},
# "Sat_BG_BA_CD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CD.png', 'lat': 52, 'long': 3, 'width': 1},
# "Sat_BG_BA_CE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_CE.png', 'lat': 52, 'long': 4, 'width': 1},
# "Sat_BG_BA_DA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DA.png', 'lat': 51, 'long': 0, 'width': 1},
# "Sat_BG_BA_DB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DB.png', 'lat': 51, 'long': 1, 'width': 1},
# "Sat_BG_BA_DC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DC.png', 'lat': 51, 'long': 2, 'width': 1},
# "Sat_BG_BA_DD.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DD.png', 'lat': 51, 'long': 3, 'width': 1},
# "Sat_BG_BA_DE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_DE.png', 'lat': 51, 'long': 4, 'width': 1},
# "Sat_BG_BA_EA.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EA.png', 'lat': 50, 'long': 0, 'width': 1},
# "Sat_BG_BA_EB.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EB.png', 'lat': 50, 'long': 1, 'width': 1},
# "Sat_BG_BA_EC.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EC.png', 'lat': 50, 'long': 2, 'width': 1},
# "Sat_BG_BA_ED.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_ED.png', 'lat': 50, 'long': 3, 'width': 1},
# "Sat_BG_BA_EE.png": {'localpath': 'Lvl2_1x1/BG_BA/', 'filename': 'Sat_BG_BA_EE.png', 'lat': 50, 'long': 4, 'width': 1},

# %%
# BB - North America - West Coast

BB_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_AA/", "Sat_BB_AA_", 55, -150)
BB_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_AB/", "Sat_BB_AB_", 55, -145)
BB_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_AC/", "Sat_BB_AC_", 55, -140)
BB_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_AD/", "Sat_BB_AD_", 55, -135)
BB_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_AE/", "Sat_BB_AE_", 55, -130)
BB_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_AF/", "Sat_BB_AF_", 55, -125)

BB_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_BA/", "Sat_BB_BA_", 50, -150)
BB_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_BB/", "Sat_BB_BB_", 50, -145)
BB_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_BC/", "Sat_BB_BC_", 50, -140)
BB_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_BD/", "Sat_BB_BD_", 50, -135)
BB_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_BE/", "Sat_BB_BE_", 50, -130)
BB_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_BF/", "Sat_BB_BF_", 50, -125)

BB_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_CA/", "Sat_BB_CA_", 45, -150)
BB_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_CB/", "Sat_BB_CB_", 45, -145)
BB_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_CC/", "Sat_BB_CC_", 45, -140)
BB_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_CD/", "Sat_BB_CD_", 45, -135)
BB_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_CE/", "Sat_BB_CE_", 45, -130)
BB_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_CF/", "Sat_BB_CF_", 45, -125)

BB_DA_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_DA/", "Sat_BB_DA_", 40, -150)
BB_DB_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_DB/", "Sat_BB_DB_", 40, -145)
BB_DC_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_DC/", "Sat_BB_DC_", 40, -140)
BB_DD_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_DD/", "Sat_BB_DD_", 40, -135)
BB_DE_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_DE/", "Sat_BB_DE_", 40, -130)
BB_DF_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_DF/", "Sat_BB_DF_", 40, -125)

BB_EA_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_EA/", "Sat_BB_EA_", 35, -150)
BB_EB_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_EB/", "Sat_BB_EB_", 35, -145)
BB_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_EC/", "Sat_BB_EC_", 35, -140)
BB_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_ED/", "Sat_BB_ED_", 35, -135)
BB_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_EE/", "Sat_BB_EE_", 35, -130)
BB_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_EF/", "Sat_BB_EF_", 35, -125)

BB_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_FA/", "Sat_BB_FA_", 30, -150)
BB_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_FB/", "Sat_BB_FB_", 30, -145)
BB_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_FC/", "Sat_BB_FC_", 30, -140)
BB_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_FD/", "Sat_BB_FD_", 30, -135)
BB_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_FE/", "Sat_BB_FE_", 30, -130)
BB_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/BB_FF/", "Sat_BB_FF_", 30, -125)

BB_1Degs_List = [
    BB_AA_1Deg, BB_AB_1Deg, BB_AC_1Deg, BB_AD_1Deg, BB_AE_1Deg, BB_AF_1Deg,
                                        BB_BD_1Deg, BB_BE_1Deg, BB_BF_1Deg,
                                                    BB_CE_1Deg, BB_CF_1Deg,
                                                                BB_DF_1Deg,
                                                                BB_EF_1Deg,
                                                                BB_FF_1Deg,
]

# %%
# BC - North America - Central

BC_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_AA/", "Sat_BC_AA_", 55, -120)
BC_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_AB/", "Sat_BC_AB_", 55, -115)
BC_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_AC/", "Sat_BC_AC_", 55, -110)
BC_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_AD/", "Sat_BC_AD_", 55, -105)
BC_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_AE/", "Sat_BC_AE_", 55, -100)
BC_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_AF/", "Sat_BC_AF_", 55,  -95)

BC_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_BA/", "Sat_BC_BA_", 50, -120)
BC_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_BB/", "Sat_BC_BB_", 50, -115)
BC_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_BC/", "Sat_BC_BC_", 50, -110)
BC_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_BD/", "Sat_BC_BD_", 50, -105)
BC_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_BE/", "Sat_BC_BE_", 50, -100)
BC_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_BF/", "Sat_BC_BF_", 50,  -95)

BC_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_CA/", "Sat_BC_CA_", 45, -120)
BC_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_CB/", "Sat_BC_CB_", 45, -115)
BC_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_CC/", "Sat_BC_CC_", 45, -110)
BC_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_CD/", "Sat_BC_CD_", 45, -105)
BC_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_CE/", "Sat_BC_CE_", 45, -100)
BC_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_CF/", "Sat_BC_CF_", 45,  -95)

BC_DA_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_DA/", "Sat_BC_DA_", 40, -120)
BC_DB_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_DB/", "Sat_BC_DB_", 40, -115)
BC_DC_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_DC/", "Sat_BC_DC_", 40, -110)
BC_DD_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_DD/", "Sat_BC_DD_", 40, -105)
BC_DE_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_DE/", "Sat_BC_DE_", 40, -100)
BC_DF_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_DF/", "Sat_BC_DF_", 40,  -95)

BC_EA_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_EA/", "Sat_BC_EA_", 35, -120)
BC_EB_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_EB/", "Sat_BC_EB_", 35, -115)
BC_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_EC/", "Sat_BC_EC_", 35, -110)
BC_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_ED/", "Sat_BC_ED_", 35, -105)
BC_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_EE/", "Sat_BC_EE_", 35, -100)
BC_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_EF/", "Sat_BC_EF_", 35,  -95)

BC_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_FA/", "Sat_BC_FA_", 30, -120)
BC_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_FB/", "Sat_BC_FB_", 30, -115)
BC_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_FC/", "Sat_BC_FC_", 30, -110)
BC_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_FD/", "Sat_BC_FD_", 30, -105)
BC_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_FE/", "Sat_BC_FE_", 30, -100)
BC_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/BC_FF/", "Sat_BC_FF_", 30,  -95)

BC_1Degs_List = [
    BC_AA_1Deg, BC_AB_1Deg, BC_AC_1Deg, BC_AD_1Deg, BC_AE_1Deg, BC_AF_1Deg,
    BC_BA_1Deg, BC_BB_1Deg, BC_BC_1Deg, BC_BD_1Deg, BC_BE_1Deg, BC_BF_1Deg,
    BC_CA_1Deg, BC_CB_1Deg, BC_CC_1Deg, BC_CD_1Deg, BC_CE_1Deg, BC_CF_1Deg,
    BC_DA_1Deg, BC_DB_1Deg, BC_DC_1Deg, BC_DD_1Deg, BC_DE_1Deg, BC_DF_1Deg,
    BC_EA_1Deg, BC_EB_1Deg, BC_EC_1Deg, BC_ED_1Deg, BC_EE_1Deg, BC_EF_1Deg,
    BC_FA_1Deg, BC_FB_1Deg, BC_FC_1Deg, BC_FD_1Deg, BC_FE_1Deg, BC_FF_1Deg,
]

# %%
# BD - North America - East

BD_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_AA/", "Sat_BD_AA_", 55, -90)
BD_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_AB/", "Sat_BD_AB_", 55, -85)
BD_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_AC/", "Sat_BD_AC_", 55, -80)
BD_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_AD/", "Sat_BD_AD_", 55, -75)
BD_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_AE/", "Sat_BD_AE_", 55, -70)
BD_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_AF/", "Sat_BD_AF_", 55, -65)

BD_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_BA/", "Sat_BD_BA_", 50, -90)
BD_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_BB/", "Sat_BD_BB_", 50, -85)
BD_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_BC/", "Sat_BD_BC_", 50, -80)
BD_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_BD/", "Sat_BD_BD_", 50, -75)
BD_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_BE/", "Sat_BD_BE_", 50, -70)
BD_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_BF/", "Sat_BD_BF_", 50, -65)

BD_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_CA/", "Sat_BD_CA_", 45, -90)
BD_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_CB/", "Sat_BD_CB_", 45, -85)
BD_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_CC/", "Sat_BD_CC_", 45, -80)
BD_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_CD/", "Sat_BD_CD_", 45, -75)
BD_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_CE/", "Sat_BD_CE_", 45, -70)
BD_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_CF/", "Sat_BD_CF_", 45, -65)

BD_DA_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_DA/", "Sat_BD_DA_", 40, -90)
BD_DB_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_DB/", "Sat_BD_DB_", 40, -85)
BD_DC_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_DC/", "Sat_BD_DC_", 40, -80)
BD_DD_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_DD/", "Sat_BD_DD_", 40, -75)
BD_DE_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_DE/", "Sat_BD_DE_", 40, -70)
BD_DF_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_DF/", "Sat_BD_DF_", 40, -65)

BD_EA_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_EA/", "Sat_BD_EA_", 35, -90)
BD_EB_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_EB/", "Sat_BD_EB_", 35, -85)
BD_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_EC/", "Sat_BD_EC_", 35, -80)
BD_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_ED/", "Sat_BD_ED_", 35, -75)
BD_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_EE/", "Sat_BD_EE_", 35, -70)
BD_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_EF/", "Sat_BD_EF_", 35, -65)

BD_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_FA/", "Sat_BD_FA_", 30, -90)
BD_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_FB/", "Sat_BD_FB_", 30, -85)
BD_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_FC/", "Sat_BD_FC_", 30, -80)
BD_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_FD/", "Sat_BD_FD_", 30, -75)
BD_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_FE/", "Sat_BD_FE_", 30, -70)
BD_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/BD_FF/", "Sat_BD_FF_", 30, -65)

BD_1Degs_List = [
    BD_AA_1Deg, BD_AB_1Deg, BD_AC_1Deg, BD_AD_1Deg, BD_AE_1Deg, BD_AF_1Deg,
    BD_BA_1Deg, BD_BB_1Deg, BD_BC_1Deg, BD_BD_1Deg, BD_BE_1Deg, BD_BF_1Deg,
    BD_CA_1Deg, BD_CB_1Deg, BD_CC_1Deg, BD_CD_1Deg, BD_CE_1Deg, BD_CF_1Deg,
    BD_DA_1Deg, BD_DB_1Deg, BD_DC_1Deg, BD_DD_1Deg, BD_DE_1Deg, BD_DF_1Deg,
    BD_EA_1Deg, BD_EB_1Deg, BD_EC_1Deg, BD_ED_1Deg,
    BD_FA_1Deg, BD_FB_1Deg, BD_FC_1Deg,
]

# %%
# BG - Europe

BG_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AA/", "Sat_BG_AA_", 55, 0)
BG_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AB/", "Sat_BG_AB_", 55, 5)
BG_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AC/", "Sat_BG_AC_", 55, 10)
BG_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AD/", "Sat_BG_AD_", 55, 15)
BG_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AE/", "Sat_BG_AE_", 55, 20)
BG_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_AF/", "Sat_BG_AF_", 55, 25)

BG_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BA/", "Sat_BG_BA_", 50, 0)
BG_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BB/", "Sat_BG_BB_", 50, 5)
BG_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BC/", "Sat_BG_BC_", 50, 10)
BG_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BD/", "Sat_BG_BD_", 50, 15)
BG_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BE/", "Sat_BG_BE_", 50, 20)
BG_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_BF/", "Sat_BG_BF_", 50, 25)

BG_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CA/", "Sat_BG_CA_", 45, 0)
BG_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CB/", "Sat_BG_CB_", 45, 5)
BG_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CC/", "Sat_BG_CC_", 45, 10)
BG_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CD/", "Sat_BG_CD_", 45, 15)
BG_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CE/", "Sat_BG_CE_", 45, 20)
BG_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_CF/", "Sat_BG_CF_", 45, 25)

BG_DA_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_DA/", "Sat_BG_DA_", 40, 0)
BG_DB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_DB/", "Sat_BG_DB_", 40, 5)
BG_DC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_DC/", "Sat_BG_DC_", 40, 10)
BG_DD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_DD/", "Sat_BG_DD_", 40, 15)
BG_DE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_DE/", "Sat_BG_DE_", 40, 20)
BG_DF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_DF/", "Sat_BG_DF_", 40, 25)

BG_EA_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_EA/", "Sat_BG_EA_", 35, 0)
BG_EB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_EB/", "Sat_BG_EB_", 35, 5)
BG_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_EC/", "Sat_BG_EC_", 35, 10)
BG_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_ED/", "Sat_BG_ED_", 35, 15)
BG_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_EE/", "Sat_BG_EE_", 35, 20)
BG_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_EF/", "Sat_BG_EF_", 35, 25)

BG_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_FA/", "Sat_BG_FA_", 30, 0)
BG_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_FB/", "Sat_BG_FB_", 30, 5)
BG_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_FC/", "Sat_BG_FC_", 30, 10)
BG_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_FD/", "Sat_BG_FD_", 30, 15)
BG_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_FE/", "Sat_BG_FE_", 30, 20)
BG_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/BG_FF/", "Sat_BG_FF_", 30, 25)

BG_1Degs_List = [
    BG_AA_1Deg, BG_AB_1Deg, BG_AC_1Deg, BG_AD_1Deg, BG_AE_1Deg, BG_AF_1Deg,
    BG_BA_1Deg, BG_BB_1Deg, BG_BC_1Deg, BG_BD_1Deg, BG_BE_1Deg, BG_BF_1Deg,
    BG_CA_1Deg, BG_CB_1Deg, BG_CC_1Deg, BG_CD_1Deg, BG_CE_1Deg, BG_CF_1Deg,
    BG_DA_1Deg, BG_DB_1Deg, BG_DC_1Deg, BG_DD_1Deg, BG_DE_1Deg, BG_DF_1Deg,
    BG_EA_1Deg, BG_EB_1Deg, BG_EC_1Deg, BG_ED_1Deg, BG_EE_1Deg, BG_EF_1Deg,
    BG_FA_1Deg, BG_FB_1Deg, BG_FC_1Deg, BG_FD_1Deg, BG_FE_1Deg, BG_FF_1Deg,
]

BG_1Degs_List = [
    BG_BB_1Deg, BG_BC_1Deg
]

# %%
# BH - Black Sea

BH_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_AA/", "Sat_BH_AA_", 55, 30)
BH_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_AB/", "Sat_BH_AB_", 55, 35)
BH_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_AC/", "Sat_BH_AC_", 55, 40)
BH_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_AD/", "Sat_BH_AD_", 55, 45)
BH_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_AE/", "Sat_BH_AE_", 55, 50)
BH_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_AF/", "Sat_BH_AF_", 55, 55)

BH_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_BA/", "Sat_BH_BA_", 50, 30)
BH_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_BB/", "Sat_BH_BB_", 50, 35)
BH_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_BC/", "Sat_BH_BC_", 50, 40)
BH_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_BD/", "Sat_BH_BD_", 50, 45)
BH_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_BE/", "Sat_BH_BE_", 50, 50)
BH_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_BF/", "Sat_BH_BF_", 50, 55)

BH_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_CA/", "Sat_BH_CA_", 45, 30)
BH_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_CB/", "Sat_BH_CB_", 45, 35)
BH_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_CC/", "Sat_BH_CC_", 45, 40)
BH_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_CD/", "Sat_BH_CD_", 45, 45)
BH_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_CE/", "Sat_BH_CE_", 45, 50)
BH_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_CF/", "Sat_BH_CF_", 45, 55)

BH_DA_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_DA/", "Sat_BH_DA_", 40, 30)
BH_DB_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_DB/", "Sat_BH_DB_", 40, 35)
BH_DC_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_DC/", "Sat_BH_DC_", 40, 40)
BH_DD_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_DD/", "Sat_BH_DD_", 40, 45)
BH_DE_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_DE/", "Sat_BH_DE_", 40, 50)
BH_DF_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_DF/", "Sat_BH_DF_", 40, 55)

BH_EA_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_EA/", "Sat_BH_EA_", 35, 30)
BH_EB_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_EB/", "Sat_BH_EB_", 35, 35)
BH_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_EC/", "Sat_BH_EC_", 35, 40)
BH_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_ED/", "Sat_BH_ED_", 35, 45)
BH_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_EE/", "Sat_BH_EE_", 35, 50)
BH_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_EF/", "Sat_BH_EF_", 35, 55)

BH_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_FA/", "Sat_BH_FA_", 30, 30)
BH_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_FB/", "Sat_BH_FB_", 30, 35)
BH_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_FC/", "Sat_BH_FC_", 30, 40)
BH_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_FD/", "Sat_BH_FD_", 30, 45)
BH_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_FE/", "Sat_BH_FE_", 30, 50)
BH_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/BH_FF/", "Sat_BH_FF_", 30, 55)

BH_1Degs_List = [
    BH_AA_1Deg, BH_AB_1Deg, BH_AC_1Deg, BH_AD_1Deg, BH_AE_1Deg, BH_AF_1Deg,
    BH_BA_1Deg, BH_BB_1Deg, BH_BC_1Deg, BH_BD_1Deg, BH_BE_1Deg, BH_BF_1Deg,
    BH_CA_1Deg, BH_CB_1Deg, BH_CC_1Deg, BH_CD_1Deg, BH_CE_1Deg, BH_CF_1Deg,
    BH_DA_1Deg, BH_DB_1Deg, BH_DC_1Deg, BH_DD_1Deg, BH_DE_1Deg, BH_DF_1Deg,
    BH_EA_1Deg, BH_EB_1Deg, BH_EC_1Deg, BH_ED_1Deg, BH_EE_1Deg, BH_EF_1Deg,
    BH_FA_1Deg, BH_FB_1Deg, BH_FC_1Deg, BH_FD_1Deg, BH_FE_1Deg, BH_FF_1Deg,
]

# %%
BE_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/BE_BA/", "Sat_BE_BA_", 50, -60)

BE_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/BE_CA/", "Sat_BE_CA_", 45, -60)
BE_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/BE_CB/", "Sat_BE_CB_", 45, -55)

BE_1Degs_List = [
    BE_BA_1Deg,
    BE_CA_1Deg, BE_CB_1Deg,
]

# %%
# CC - Mexico

CC_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_AA/", "Sat_CC_AA_", 25, -120)
CC_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_AB/", "Sat_CC_AB_", 25, -115)
CC_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_AC/", "Sat_CC_AC_", 25, -110)
CC_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_AD/", "Sat_CC_AD_", 25, -105)
CC_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_AE/", "Sat_CC_AE_", 25, -100)
CC_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_AF/", "Sat_CC_AF_", 25,  -95)

CC_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_BA/", "Sat_CC_BA_", 20, -120)
CC_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_BB/", "Sat_CC_BB_", 20, -115)
CC_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_BC/", "Sat_CC_BC_", 20, -110)
CC_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_BD/", "Sat_CC_BD_", 20, -105)
CC_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_BE/", "Sat_CC_BE_", 20, -100)
CC_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_BF/", "Sat_CC_BF_", 20,  -95)

CC_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_CA/", "Sat_CC_CA_", 15, -120)
CC_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_CB/", "Sat_CC_CB_", 15, -115)
CC_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_CC/", "Sat_CC_CC_", 15, -110)
CC_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_CD/", "Sat_CC_CD_", 15, -105)
CC_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_CE/", "Sat_CC_CE_", 15, -100)
CC_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_CF/", "Sat_CC_CF_", 15,  -95)

CC_DA_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_DA/", "Sat_CC_DA_", 10, -120)
CC_DB_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_DB/", "Sat_CC_DB_", 10, -115)
CC_DC_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_DC/", "Sat_CC_DC_", 10, -110)
CC_DD_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_DD/", "Sat_CC_DD_", 10, -105)
CC_DE_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_DE/", "Sat_CC_DE_", 10, -100)
CC_DF_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_DF/", "Sat_CC_DF_", 10,  -95)

CC_EA_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_EA/", "Sat_CC_EA_",  5, -120)
CC_EB_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_EB/", "Sat_CC_EB_",  5, -115)
CC_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_EC/", "Sat_CC_EC_",  5, -110)
CC_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_ED/", "Sat_CC_ED_",  5, -105)
CC_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_EE/", "Sat_CC_EE_",  5, -100)
CC_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_EF/", "Sat_CC_EF_",  5,  -95)

CC_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_FA/", "Sat_CC_FA_",  0, -120)
CC_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_FB/", "Sat_CC_FB_",  0, -115)
CC_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_FC/", "Sat_CC_FC_",  0, -110)
CC_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_FD/", "Sat_CC_FD_",  0, -105)
CC_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_FE/", "Sat_CC_FE_",  0, -100)
CC_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/CC_FF/", "Sat_CC_FF_",  0,  -95)

CC_1Degs_List = [
    CC_AA_1Deg, CC_AB_1Deg, CC_AC_1Deg, CC_AD_1Deg, CC_AE_1Deg, CC_AF_1Deg,
                CC_BB_1Deg, CC_BC_1Deg, CC_BD_1Deg, CC_BE_1Deg, CC_BF_1Deg,
                            CC_CC_1Deg, CC_CD_1Deg, CC_CE_1Deg, CC_CF_1Deg,
                                        CC_DD_1Deg, CC_DE_1Deg, CC_DF_1Deg,

]

# %%
# CD - Cuba

CD_AA_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_AA/", "Sat_CD_AA_", 25, -90)
CD_AB_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_AB/", "Sat_CD_AB_", 25, -85)
CD_AC_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_AC/", "Sat_CD_AC_", 25, -80)
CD_AD_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_AD/", "Sat_CD_AD_", 25, -75)
CD_AE_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_AE/", "Sat_CD_AE_", 25, -70)
CD_AF_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_AF/", "Sat_CD_AF_", 25, -65)

CD_BA_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_BA/", "Sat_CD_BA_", 20, -90)
CD_BB_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_BB/", "Sat_CD_BB_", 20, -85)
CD_BC_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_BC/", "Sat_CD_BC_", 20, -80)
CD_BD_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_BD/", "Sat_CD_BD_", 20, -75)
CD_BE_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_BE/", "Sat_CD_BE_", 20, -70)
CD_BF_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_BF/", "Sat_CD_BF_", 20, -65)

CD_CA_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_CA/", "Sat_CD_CA_", 15, -90)
CD_CB_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_CB/", "Sat_CD_CB_", 15, -85)
CD_CC_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_CC/", "Sat_CD_CC_", 15, -80)
CD_CD_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_CD/", "Sat_CD_CD_", 15, -75)
CD_CE_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_CE/", "Sat_CD_CE_", 15, -70)
CD_CF_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_CF/", "Sat_CD_CF_", 15, -65)

CD_DA_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_DA/", "Sat_CD_DA_", 10, -90)
CD_DB_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_DB/", "Sat_CD_DB_", 10, -85)
CD_DC_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_DC/", "Sat_CD_DC_", 10, -80)
CD_DD_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_DD/", "Sat_CD_DD_", 10, -75)
CD_DE_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_DE/", "Sat_CD_DE_", 10, -70)
CD_DF_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_DF/", "Sat_CD_DF_", 10, -65)

CD_EA_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_EA/", "Sat_CD_EA_",  5, -90)
CD_EB_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_EB/", "Sat_CD_EB_",  5, -85)
CD_EC_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_EC/", "Sat_CD_EC_",  5, -80)
CD_ED_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_ED/", "Sat_CD_ED_",  5, -75)
CD_EE_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_EE/", "Sat_CD_EE_",  5, -70)
CD_EF_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_EF/", "Sat_CD_EF_",  5, -65)

CD_FA_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_FA/", "Sat_CD_FA_",  0, -90)
CD_FB_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_FB/", "Sat_CD_FB_",  0, -85)
CD_FC_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_FC/", "Sat_CD_FC_",  0, -80)
CD_FD_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_FD/", "Sat_CD_FD_",  0, -75)
CD_FE_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_FE/", "Sat_CD_FE_",  0, -70)
CD_FF_1Deg = create_1deg_dictionary("Lvl2_1x1/CD_FF/", "Sat_CD_FF_",  0, -65)

CD_1Degs_List = [
    CD_AA_1Deg, CD_AB_1Deg, CD_AC_1Deg,
    CD_BA_1Deg, CD_BB_1Deg, CD_BC_1Deg, CD_BD_1Deg,
    CD_CA_1Deg, CD_CB_1Deg, CD_CC_1Deg, CD_CD_1Deg, CD_CE_1Deg, CD_CF_1Deg,
    CD_DA_1Deg, CD_DB_1Deg, CD_DC_1Deg, CD_DD_1Deg, CD_DE_1Deg, CD_DF_1Deg,
    CD_EA_1Deg, CD_EB_1Deg, CD_EC_1Deg, CD_ED_1Deg, CD_EE_1Deg, CD_EF_1Deg,
                            CD_FC_1Deg, CD_FD_1Deg, CD_FE_1Deg, CD_FF_1Deg,
]

# Loop through the dictionaries, and then fields
for dictionary in CD_1Degs_List:
    for key, value in dictionary.items():
        print(f"\"{key}\": {value},")
# Out:
# "Sat_CD_AA_AA.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_AA.png', 'lat': 29, 'long': -90, 'width': 1},
# "Sat_CD_AA_AB.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_AB.png', 'lat': 29, 'long': -89, 'width': 1},
# "Sat_CD_AA_AC.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_AC.png', 'lat': 29, 'long': -88, 'width': 1},
# "Sat_CD_AA_AD.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_AD.png', 'lat': 29, 'long': -87, 'width': 1},
# "Sat_CD_AA_AE.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_AE.png', 'lat': 29, 'long': -86, 'width': 1},
# "Sat_CD_AA_BA.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_BA.png', 'lat': 28, 'long': -90, 'width': 1},
# "Sat_CD_AA_BB.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_BB.png', 'lat': 28, 'long': -89, 'width': 1},
# "Sat_CD_AA_BC.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_BC.png', 'lat': 28, 'long': -88, 'width': 1},
# "Sat_CD_AA_BD.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_BD.png', 'lat': 28, 'long': -87, 'width': 1},
# "Sat_CD_AA_BE.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_BE.png', 'lat': 28, 'long': -86, 'width': 1},
# "Sat_CD_AA_CA.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_CA.png', 'lat': 27, 'long': -90, 'width': 1},
# "Sat_CD_AA_CB.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_CB.png', 'lat': 27, 'long': -89, 'width': 1},
# "Sat_CD_AA_CC.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_CC.png', 'lat': 27, 'long': -88, 'width': 1},
# "Sat_CD_AA_CD.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_CD.png', 'lat': 27, 'long': -87, 'width': 1},
# "Sat_CD_AA_CE.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_CE.png', 'lat': 27, 'long': -86, 'width': 1},
# "Sat_CD_AA_DA.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_DA.png', 'lat': 26, 'long': -90, 'width': 1},
# "Sat_CD_AA_DB.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_DB.png', 'lat': 26, 'long': -89, 'width': 1},
# "Sat_CD_AA_DC.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_DC.png', 'lat': 26, 'long': -88, 'width': 1},
# "Sat_CD_AA_DD.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_DD.png', 'lat': 26, 'long': -87, 'width': 1},
# "Sat_CD_AA_DE.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_DE.png', 'lat': 26, 'long': -86, 'width': 1},
# "Sat_CD_AA_EA.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_EA.png', 'lat': 25, 'long': -90, 'width': 1},
# "Sat_CD_AA_EB.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_EB.png', 'lat': 25, 'long': -89, 'width': 1},
# "Sat_CD_AA_EC.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_EC.png', 'lat': 25, 'long': -88, 'width': 1},
# "Sat_CD_AA_ED.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_ED.png', 'lat': 25, 'long': -87, 'width': 1},
# "Sat_CD_AA_EE.png": {'localpath': 'Lvl2_1x1/CD_AA/', 'filename': 'Sat_CD_AA_EE.png', 'lat': 25, 'long': -86, 'width': 1},
# "Sat_CD_AB_AA.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_AA.png', 'lat': 29, 'long': -85, 'width': 1},
# "Sat_CD_AB_AB.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_AB.png', 'lat': 29, 'long': -84, 'width': 1},
# "Sat_CD_AB_AC.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_AC.png', 'lat': 29, 'long': -83, 'width': 1},
# "Sat_CD_AB_AD.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_AD.png', 'lat': 29, 'long': -82, 'width': 1},
# "Sat_CD_AB_AE.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_AE.png', 'lat': 29, 'long': -81, 'width': 1},
# "Sat_CD_AB_BA.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_BA.png', 'lat': 28, 'long': -85, 'width': 1},
# "Sat_CD_AB_BB.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_BB.png', 'lat': 28, 'long': -84, 'width': 1},
# "Sat_CD_AB_BC.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_BC.png', 'lat': 28, 'long': -83, 'width': 1},
# "Sat_CD_AB_BD.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_BD.png', 'lat': 28, 'long': -82, 'width': 1},
# "Sat_CD_AB_BE.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_BE.png', 'lat': 28, 'long': -81, 'width': 1},
# "Sat_CD_AB_CA.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_CA.png', 'lat': 27, 'long': -85, 'width': 1},
# "Sat_CD_AB_CB.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_CB.png', 'lat': 27, 'long': -84, 'width': 1},
# "Sat_CD_AB_CC.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_CC.png', 'lat': 27, 'long': -83, 'width': 1},
# "Sat_CD_AB_CD.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_CD.png', 'lat': 27, 'long': -82, 'width': 1},
# "Sat_CD_AB_CE.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_CE.png', 'lat': 27, 'long': -81, 'width': 1},
# "Sat_CD_AB_DA.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_DA.png', 'lat': 26, 'long': -85, 'width': 1},
# "Sat_CD_AB_DB.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_DB.png', 'lat': 26, 'long': -84, 'width': 1},
# "Sat_CD_AB_DC.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_DC.png', 'lat': 26, 'long': -83, 'width': 1},
# "Sat_CD_AB_DD.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_DD.png', 'lat': 26, 'long': -82, 'width': 1},
# "Sat_CD_AB_DE.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_DE.png', 'lat': 26, 'long': -81, 'width': 1},
# "Sat_CD_AB_EA.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_EA.png', 'lat': 25, 'long': -85, 'width': 1},
# "Sat_CD_AB_EB.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_EB.png', 'lat': 25, 'long': -84, 'width': 1},
# "Sat_CD_AB_EC.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_EC.png', 'lat': 25, 'long': -83, 'width': 1},
# "Sat_CD_AB_ED.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_ED.png', 'lat': 25, 'long': -82, 'width': 1},
# "Sat_CD_AB_EE.png": {'localpath': 'Lvl2_1x1/CD_AB/', 'filename': 'Sat_CD_AB_EE.png', 'lat': 25, 'long': -81, 'width': 1},
# "Sat_CD_AC_AA.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_AA.png', 'lat': 29, 'long': -80, 'width': 1},
# "Sat_CD_AC_AB.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_AB.png', 'lat': 29, 'long': -79, 'width': 1},
# "Sat_CD_AC_AC.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_AC.png', 'lat': 29, 'long': -78, 'width': 1},
# "Sat_CD_AC_AD.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_AD.png', 'lat': 29, 'long': -77, 'width': 1},
# "Sat_CD_AC_AE.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_AE.png', 'lat': 29, 'long': -76, 'width': 1},
# "Sat_CD_AC_BA.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_BA.png', 'lat': 28, 'long': -80, 'width': 1},
# "Sat_CD_AC_BB.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_BB.png', 'lat': 28, 'long': -79, 'width': 1},
# "Sat_CD_AC_BC.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_BC.png', 'lat': 28, 'long': -78, 'width': 1},
# "Sat_CD_AC_BD.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_BD.png', 'lat': 28, 'long': -77, 'width': 1},
# "Sat_CD_AC_BE.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_BE.png', 'lat': 28, 'long': -76, 'width': 1},
# "Sat_CD_AC_CA.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_CA.png', 'lat': 27, 'long': -80, 'width': 1},
# "Sat_CD_AC_CB.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_CB.png', 'lat': 27, 'long': -79, 'width': 1},
# "Sat_CD_AC_CC.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_CC.png', 'lat': 27, 'long': -78, 'width': 1},
# "Sat_CD_AC_CD.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_CD.png', 'lat': 27, 'long': -77, 'width': 1},
# "Sat_CD_AC_CE.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_CE.png', 'lat': 27, 'long': -76, 'width': 1},
# "Sat_CD_AC_DA.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_DA.png', 'lat': 26, 'long': -80, 'width': 1},
# "Sat_CD_AC_DB.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_DB.png', 'lat': 26, 'long': -79, 'width': 1},
# "Sat_CD_AC_DC.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_DC.png', 'lat': 26, 'long': -78, 'width': 1},
# "Sat_CD_AC_DD.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_DD.png', 'lat': 26, 'long': -77, 'width': 1},
# "Sat_CD_AC_DE.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_DE.png', 'lat': 26, 'long': -76, 'width': 1},
# "Sat_CD_AC_EA.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_EA.png', 'lat': 25, 'long': -80, 'width': 1},
# "Sat_CD_AC_EB.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_EB.png', 'lat': 25, 'long': -79, 'width': 1},
# "Sat_CD_AC_EC.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_EC.png', 'lat': 25, 'long': -78, 'width': 1},
# "Sat_CD_AC_ED.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_ED.png', 'lat': 25, 'long': -77, 'width': 1},
# "Sat_CD_AC_EE.png": {'localpath': 'Lvl2_1x1/CD_AC/', 'filename': 'Sat_CD_AC_EE.png', 'lat': 25, 'long': -76, 'width': 1},
# "Sat_CD_BA_AA.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_AA.png', 'lat': 24, 'long': -90, 'width': 1},
# "Sat_CD_BA_AB.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_AB.png', 'lat': 24, 'long': -89, 'width': 1},
# "Sat_CD_BA_AC.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_AC.png', 'lat': 24, 'long': -88, 'width': 1},
# "Sat_CD_BA_AD.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_AD.png', 'lat': 24, 'long': -87, 'width': 1},
# "Sat_CD_BA_AE.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_AE.png', 'lat': 24, 'long': -86, 'width': 1},
# "Sat_CD_BA_BA.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_BA.png', 'lat': 23, 'long': -90, 'width': 1},
# "Sat_CD_BA_BB.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_BB.png', 'lat': 23, 'long': -89, 'width': 1},
# "Sat_CD_BA_BC.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_BC.png', 'lat': 23, 'long': -88, 'width': 1},
# "Sat_CD_BA_BD.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_BD.png', 'lat': 23, 'long': -87, 'width': 1},
# "Sat_CD_BA_BE.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_BE.png', 'lat': 23, 'long': -86, 'width': 1},
# "Sat_CD_BA_CA.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_CA.png', 'lat': 22, 'long': -90, 'width': 1},
# "Sat_CD_BA_CB.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_CB.png', 'lat': 22, 'long': -89, 'width': 1},
# "Sat_CD_BA_CC.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_CC.png', 'lat': 22, 'long': -88, 'width': 1},
# "Sat_CD_BA_CD.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_CD.png', 'lat': 22, 'long': -87, 'width': 1},
# "Sat_CD_BA_CE.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_CE.png', 'lat': 22, 'long': -86, 'width': 1},
# "Sat_CD_BA_DA.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_DA.png', 'lat': 21, 'long': -90, 'width': 1},
# "Sat_CD_BA_DB.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_DB.png', 'lat': 21, 'long': -89, 'width': 1},
# "Sat_CD_BA_DC.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_DC.png', 'lat': 21, 'long': -88, 'width': 1},
# "Sat_CD_BA_DD.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_DD.png', 'lat': 21, 'long': -87, 'width': 1},
# "Sat_CD_BA_DE.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_DE.png', 'lat': 21, 'long': -86, 'width': 1},
# "Sat_CD_BA_EA.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_EA.png', 'lat': 20, 'long': -90, 'width': 1},
# "Sat_CD_BA_EB.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_EB.png', 'lat': 20, 'long': -89, 'width': 1},
# "Sat_CD_BA_EC.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_EC.png', 'lat': 20, 'long': -88, 'width': 1},
# "Sat_CD_BA_ED.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_ED.png', 'lat': 20, 'long': -87, 'width': 1},
# "Sat_CD_BA_EE.png": {'localpath': 'Lvl2_1x1/CD_BA/', 'filename': 'Sat_CD_BA_EE.png', 'lat': 20, 'long': -86, 'width': 1},
# "Sat_CD_BB_AA.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_AA.png', 'lat': 24, 'long': -85, 'width': 1},
# "Sat_CD_BB_AB.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_AB.png', 'lat': 24, 'long': -84, 'width': 1},
# "Sat_CD_BB_AC.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_AC.png', 'lat': 24, 'long': -83, 'width': 1},
# "Sat_CD_BB_AD.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_AD.png', 'lat': 24, 'long': -82, 'width': 1},
# "Sat_CD_BB_AE.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_AE.png', 'lat': 24, 'long': -81, 'width': 1},
# "Sat_CD_BB_BA.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_BA.png', 'lat': 23, 'long': -85, 'width': 1},
# "Sat_CD_BB_BB.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_BB.png', 'lat': 23, 'long': -84, 'width': 1},
# "Sat_CD_BB_BC.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_BC.png', 'lat': 23, 'long': -83, 'width': 1},
# "Sat_CD_BB_BD.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_BD.png', 'lat': 23, 'long': -82, 'width': 1},
# "Sat_CD_BB_BE.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_BE.png', 'lat': 23, 'long': -81, 'width': 1},
# "Sat_CD_BB_CA.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_CA.png', 'lat': 22, 'long': -85, 'width': 1},
# "Sat_CD_BB_CB.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_CB.png', 'lat': 22, 'long': -84, 'width': 1},
# "Sat_CD_BB_CC.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_CC.png', 'lat': 22, 'long': -83, 'width': 1},
# "Sat_CD_BB_CD.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_CD.png', 'lat': 22, 'long': -82, 'width': 1},
# "Sat_CD_BB_CE.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_CE.png', 'lat': 22, 'long': -81, 'width': 1},
# "Sat_CD_BB_DA.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_DA.png', 'lat': 21, 'long': -85, 'width': 1},
# "Sat_CD_BB_DB.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_DB.png', 'lat': 21, 'long': -84, 'width': 1},
# "Sat_CD_BB_DC.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_DC.png', 'lat': 21, 'long': -83, 'width': 1},
# "Sat_CD_BB_DD.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_DD.png', 'lat': 21, 'long': -82, 'width': 1},
# "Sat_CD_BB_DE.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_DE.png', 'lat': 21, 'long': -81, 'width': 1},
# "Sat_CD_BB_EA.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_EA.png', 'lat': 20, 'long': -85, 'width': 1},
# "Sat_CD_BB_EB.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_EB.png', 'lat': 20, 'long': -84, 'width': 1},
# "Sat_CD_BB_EC.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_EC.png', 'lat': 20, 'long': -83, 'width': 1},
# "Sat_CD_BB_ED.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_ED.png', 'lat': 20, 'long': -82, 'width': 1},
# "Sat_CD_BB_EE.png": {'localpath': 'Lvl2_1x1/CD_BB/', 'filename': 'Sat_CD_BB_EE.png', 'lat': 20, 'long': -81, 'width': 1},
# "Sat_CD_BC_AA.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_AA.png', 'lat': 24, 'long': -80, 'width': 1},
# "Sat_CD_BC_AB.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_AB.png', 'lat': 24, 'long': -79, 'width': 1},
# "Sat_CD_BC_AC.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_AC.png', 'lat': 24, 'long': -78, 'width': 1},
# "Sat_CD_BC_AD.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_AD.png', 'lat': 24, 'long': -77, 'width': 1},
# "Sat_CD_BC_AE.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_AE.png', 'lat': 24, 'long': -76, 'width': 1},
# "Sat_CD_BC_BA.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_BA.png', 'lat': 23, 'long': -80, 'width': 1},
# "Sat_CD_BC_BB.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_BB.png', 'lat': 23, 'long': -79, 'width': 1},
# "Sat_CD_BC_BC.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_BC.png', 'lat': 23, 'long': -78, 'width': 1},
# "Sat_CD_BC_BD.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_BD.png', 'lat': 23, 'long': -77, 'width': 1},
# "Sat_CD_BC_BE.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_BE.png', 'lat': 23, 'long': -76, 'width': 1},
# "Sat_CD_BC_CA.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_CA.png', 'lat': 22, 'long': -80, 'width': 1},
# "Sat_CD_BC_CB.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_CB.png', 'lat': 22, 'long': -79, 'width': 1},
# "Sat_CD_BC_CC.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_CC.png', 'lat': 22, 'long': -78, 'width': 1},
# "Sat_CD_BC_CD.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_CD.png', 'lat': 22, 'long': -77, 'width': 1},
# "Sat_CD_BC_CE.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_CE.png', 'lat': 22, 'long': -76, 'width': 1},
# "Sat_CD_BC_DA.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_DA.png', 'lat': 21, 'long': -80, 'width': 1},
# "Sat_CD_BC_DB.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_DB.png', 'lat': 21, 'long': -79, 'width': 1},
# "Sat_CD_BC_DC.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_DC.png', 'lat': 21, 'long': -78, 'width': 1},
# "Sat_CD_BC_DD.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_DD.png', 'lat': 21, 'long': -77, 'width': 1},
# "Sat_CD_BC_DE.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_DE.png', 'lat': 21, 'long': -76, 'width': 1},
# "Sat_CD_BC_EA.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_EA.png', 'lat': 20, 'long': -80, 'width': 1},
# "Sat_CD_BC_EB.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_EB.png', 'lat': 20, 'long': -79, 'width': 1},
# "Sat_CD_BC_EC.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_EC.png', 'lat': 20, 'long': -78, 'width': 1},
# "Sat_CD_BC_ED.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_ED.png', 'lat': 20, 'long': -77, 'width': 1},
# "Sat_CD_BC_EE.png": {'localpath': 'Lvl2_1x1/CD_BC/', 'filename': 'Sat_CD_BC_EE.png', 'lat': 20, 'long': -76, 'width': 1},
# "Sat_CD_BD_AA.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_AA.png', 'lat': 24, 'long': -75, 'width': 1},
# "Sat_CD_BD_AB.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_AB.png', 'lat': 24, 'long': -74, 'width': 1},
# "Sat_CD_BD_AC.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_AC.png', 'lat': 24, 'long': -73, 'width': 1},
# "Sat_CD_BD_AD.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_AD.png', 'lat': 24, 'long': -72, 'width': 1},
# "Sat_CD_BD_AE.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_AE.png', 'lat': 24, 'long': -71, 'width': 1},
# "Sat_CD_BD_BA.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_BA.png', 'lat': 23, 'long': -75, 'width': 1},
# "Sat_CD_BD_BB.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_BB.png', 'lat': 23, 'long': -74, 'width': 1},
# "Sat_CD_BD_BC.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_BC.png', 'lat': 23, 'long': -73, 'width': 1},
# "Sat_CD_BD_BD.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_BD.png', 'lat': 23, 'long': -72, 'width': 1},
# "Sat_CD_BD_BE.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_BE.png', 'lat': 23, 'long': -71, 'width': 1},
# "Sat_CD_BD_CA.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_CA.png', 'lat': 22, 'long': -75, 'width': 1},
# "Sat_CD_BD_CB.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_CB.png', 'lat': 22, 'long': -74, 'width': 1},
# "Sat_CD_BD_CC.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_CC.png', 'lat': 22, 'long': -73, 'width': 1},
# "Sat_CD_BD_CD.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_CD.png', 'lat': 22, 'long': -72, 'width': 1},
# "Sat_CD_BD_CE.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_CE.png', 'lat': 22, 'long': -71, 'width': 1},
# "Sat_CD_BD_DA.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_DA.png', 'lat': 21, 'long': -75, 'width': 1},
# "Sat_CD_BD_DB.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_DB.png', 'lat': 21, 'long': -74, 'width': 1},
# "Sat_CD_BD_DC.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_DC.png', 'lat': 21, 'long': -73, 'width': 1},
# "Sat_CD_BD_DD.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_DD.png', 'lat': 21, 'long': -72, 'width': 1},
# "Sat_CD_BD_DE.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_DE.png', 'lat': 21, 'long': -71, 'width': 1},
# "Sat_CD_BD_EA.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_EA.png', 'lat': 20, 'long': -75, 'width': 1},
# "Sat_CD_BD_EB.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_EB.png', 'lat': 20, 'long': -74, 'width': 1},
# "Sat_CD_BD_EC.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_EC.png', 'lat': 20, 'long': -73, 'width': 1},
# "Sat_CD_BD_ED.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_ED.png', 'lat': 20, 'long': -72, 'width': 1},
# "Sat_CD_BD_EE.png": {'localpath': 'Lvl2_1x1/CD_BD/', 'filename': 'Sat_CD_BD_EE.png', 'lat': 20, 'long': -71, 'width': 1},
# "Sat_CD_CA_AA.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_AA.png', 'lat': 19, 'long': -90, 'width': 1},
# "Sat_CD_CA_AB.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_AB.png', 'lat': 19, 'long': -89, 'width': 1},
# "Sat_CD_CA_AC.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_AC.png', 'lat': 19, 'long': -88, 'width': 1},
# "Sat_CD_CA_AD.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_AD.png', 'lat': 19, 'long': -87, 'width': 1},
# "Sat_CD_CA_AE.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_AE.png', 'lat': 19, 'long': -86, 'width': 1},
# "Sat_CD_CA_BA.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_BA.png', 'lat': 18, 'long': -90, 'width': 1},
# "Sat_CD_CA_BB.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_BB.png', 'lat': 18, 'long': -89, 'width': 1},
# "Sat_CD_CA_BC.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_BC.png', 'lat': 18, 'long': -88, 'width': 1},
# "Sat_CD_CA_BD.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_BD.png', 'lat': 18, 'long': -87, 'width': 1},
# "Sat_CD_CA_BE.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_BE.png', 'lat': 18, 'long': -86, 'width': 1},
# "Sat_CD_CA_CA.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_CA.png', 'lat': 17, 'long': -90, 'width': 1},
# "Sat_CD_CA_CB.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_CB.png', 'lat': 17, 'long': -89, 'width': 1},
# "Sat_CD_CA_CC.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_CC.png', 'lat': 17, 'long': -88, 'width': 1},
# "Sat_CD_CA_CD.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_CD.png', 'lat': 17, 'long': -87, 'width': 1},
# "Sat_CD_CA_CE.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_CE.png', 'lat': 17, 'long': -86, 'width': 1},
# "Sat_CD_CA_DA.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_DA.png', 'lat': 16, 'long': -90, 'width': 1},
# "Sat_CD_CA_DB.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_DB.png', 'lat': 16, 'long': -89, 'width': 1},
# "Sat_CD_CA_DC.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_DC.png', 'lat': 16, 'long': -88, 'width': 1},
# "Sat_CD_CA_DD.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_DD.png', 'lat': 16, 'long': -87, 'width': 1},
# "Sat_CD_CA_DE.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_DE.png', 'lat': 16, 'long': -86, 'width': 1},
# "Sat_CD_CA_EA.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_EA.png', 'lat': 15, 'long': -90, 'width': 1},
# "Sat_CD_CA_EB.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_EB.png', 'lat': 15, 'long': -89, 'width': 1},
# "Sat_CD_CA_EC.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_EC.png', 'lat': 15, 'long': -88, 'width': 1},
# "Sat_CD_CA_ED.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_ED.png', 'lat': 15, 'long': -87, 'width': 1},
# "Sat_CD_CA_EE.png": {'localpath': 'Lvl2_1x1/CD_CA/', 'filename': 'Sat_CD_CA_EE.png', 'lat': 15, 'long': -86, 'width': 1},
# "Sat_CD_CB_AA.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_AA.png', 'lat': 19, 'long': -85, 'width': 1},
# "Sat_CD_CB_AB.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_AB.png', 'lat': 19, 'long': -84, 'width': 1},
# "Sat_CD_CB_AC.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_AC.png', 'lat': 19, 'long': -83, 'width': 1},
# "Sat_CD_CB_AD.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_AD.png', 'lat': 19, 'long': -82, 'width': 1},
# "Sat_CD_CB_AE.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_AE.png', 'lat': 19, 'long': -81, 'width': 1},
# "Sat_CD_CB_BA.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_BA.png', 'lat': 18, 'long': -85, 'width': 1},
# "Sat_CD_CB_BB.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_BB.png', 'lat': 18, 'long': -84, 'width': 1},
# "Sat_CD_CB_BC.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_BC.png', 'lat': 18, 'long': -83, 'width': 1},
# "Sat_CD_CB_BD.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_BD.png', 'lat': 18, 'long': -82, 'width': 1},
# "Sat_CD_CB_BE.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_BE.png', 'lat': 18, 'long': -81, 'width': 1},
# "Sat_CD_CB_CA.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_CA.png', 'lat': 17, 'long': -85, 'width': 1},
# "Sat_CD_CB_CB.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_CB.png', 'lat': 17, 'long': -84, 'width': 1},
# "Sat_CD_CB_CC.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_CC.png', 'lat': 17, 'long': -83, 'width': 1},
# "Sat_CD_CB_CD.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_CD.png', 'lat': 17, 'long': -82, 'width': 1},
# "Sat_CD_CB_CE.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_CE.png', 'lat': 17, 'long': -81, 'width': 1},
# "Sat_CD_CB_DA.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_DA.png', 'lat': 16, 'long': -85, 'width': 1},
# "Sat_CD_CB_DB.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_DB.png', 'lat': 16, 'long': -84, 'width': 1},
# "Sat_CD_CB_DC.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_DC.png', 'lat': 16, 'long': -83, 'width': 1},
# "Sat_CD_CB_DD.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_DD.png', 'lat': 16, 'long': -82, 'width': 1},
# "Sat_CD_CB_DE.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_DE.png', 'lat': 16, 'long': -81, 'width': 1},
# "Sat_CD_CB_EA.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_EA.png', 'lat': 15, 'long': -85, 'width': 1},
# "Sat_CD_CB_EB.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_EB.png', 'lat': 15, 'long': -84, 'width': 1},
# "Sat_CD_CB_EC.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_EC.png', 'lat': 15, 'long': -83, 'width': 1},
# "Sat_CD_CB_ED.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_ED.png', 'lat': 15, 'long': -82, 'width': 1},
# "Sat_CD_CB_EE.png": {'localpath': 'Lvl2_1x1/CD_CB/', 'filename': 'Sat_CD_CB_EE.png', 'lat': 15, 'long': -81, 'width': 1},
# "Sat_CD_CC_AA.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_AA.png', 'lat': 19, 'long': -80, 'width': 1},
# "Sat_CD_CC_AB.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_AB.png', 'lat': 19, 'long': -79, 'width': 1},
# "Sat_CD_CC_AC.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_AC.png', 'lat': 19, 'long': -78, 'width': 1},
# "Sat_CD_CC_AD.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_AD.png', 'lat': 19, 'long': -77, 'width': 1},
# "Sat_CD_CC_AE.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_AE.png', 'lat': 19, 'long': -76, 'width': 1},
# "Sat_CD_CC_BA.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_BA.png', 'lat': 18, 'long': -80, 'width': 1},
# "Sat_CD_CC_BB.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_BB.png', 'lat': 18, 'long': -79, 'width': 1},
# "Sat_CD_CC_BC.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_BC.png', 'lat': 18, 'long': -78, 'width': 1},
# "Sat_CD_CC_BD.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_BD.png', 'lat': 18, 'long': -77, 'width': 1},
# "Sat_CD_CC_BE.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_BE.png', 'lat': 18, 'long': -76, 'width': 1},
# "Sat_CD_CC_CA.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_CA.png', 'lat': 17, 'long': -80, 'width': 1},
# "Sat_CD_CC_CB.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_CB.png', 'lat': 17, 'long': -79, 'width': 1},
# "Sat_CD_CC_CC.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_CC.png', 'lat': 17, 'long': -78, 'width': 1},
# "Sat_CD_CC_CD.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_CD.png', 'lat': 17, 'long': -77, 'width': 1},
# "Sat_CD_CC_CE.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_CE.png', 'lat': 17, 'long': -76, 'width': 1},
# "Sat_CD_CC_DA.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_DA.png', 'lat': 16, 'long': -80, 'width': 1},
# "Sat_CD_CC_DB.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_DB.png', 'lat': 16, 'long': -79, 'width': 1},
# "Sat_CD_CC_DC.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_DC.png', 'lat': 16, 'long': -78, 'width': 1},
# "Sat_CD_CC_DD.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_DD.png', 'lat': 16, 'long': -77, 'width': 1},
# "Sat_CD_CC_DE.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_DE.png', 'lat': 16, 'long': -76, 'width': 1},
# "Sat_CD_CC_EA.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_EA.png', 'lat': 15, 'long': -80, 'width': 1},
# "Sat_CD_CC_EB.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_EB.png', 'lat': 15, 'long': -79, 'width': 1},
# "Sat_CD_CC_EC.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_EC.png', 'lat': 15, 'long': -78, 'width': 1},
# "Sat_CD_CC_ED.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_ED.png', 'lat': 15, 'long': -77, 'width': 1},
# "Sat_CD_CC_EE.png": {'localpath': 'Lvl2_1x1/CD_CC/', 'filename': 'Sat_CD_CC_EE.png', 'lat': 15, 'long': -76, 'width': 1},
# "Sat_CD_CD_AA.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_AA.png', 'lat': 19, 'long': -75, 'width': 1},
# "Sat_CD_CD_AB.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_AB.png', 'lat': 19, 'long': -74, 'width': 1},
# "Sat_CD_CD_AC.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_AC.png', 'lat': 19, 'long': -73, 'width': 1},
# "Sat_CD_CD_AD.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_AD.png', 'lat': 19, 'long': -72, 'width': 1},
# "Sat_CD_CD_AE.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_AE.png', 'lat': 19, 'long': -71, 'width': 1},
# "Sat_CD_CD_BA.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_BA.png', 'lat': 18, 'long': -75, 'width': 1},
# "Sat_CD_CD_BB.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_BB.png', 'lat': 18, 'long': -74, 'width': 1},
# "Sat_CD_CD_BC.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_BC.png', 'lat': 18, 'long': -73, 'width': 1},
# "Sat_CD_CD_BD.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_BD.png', 'lat': 18, 'long': -72, 'width': 1},
# "Sat_CD_CD_BE.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_BE.png', 'lat': 18, 'long': -71, 'width': 1},
# "Sat_CD_CD_CA.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_CA.png', 'lat': 17, 'long': -75, 'width': 1},
# "Sat_CD_CD_CB.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_CB.png', 'lat': 17, 'long': -74, 'width': 1},
# "Sat_CD_CD_CC.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_CC.png', 'lat': 17, 'long': -73, 'width': 1},
# "Sat_CD_CD_CD.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_CD.png', 'lat': 17, 'long': -72, 'width': 1},
# "Sat_CD_CD_CE.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_CE.png', 'lat': 17, 'long': -71, 'width': 1},
# "Sat_CD_CD_DA.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_DA.png', 'lat': 16, 'long': -75, 'width': 1},
# "Sat_CD_CD_DB.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_DB.png', 'lat': 16, 'long': -74, 'width': 1},
# "Sat_CD_CD_DC.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_DC.png', 'lat': 16, 'long': -73, 'width': 1},
# "Sat_CD_CD_DD.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_DD.png', 'lat': 16, 'long': -72, 'width': 1},
# "Sat_CD_CD_DE.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_DE.png', 'lat': 16, 'long': -71, 'width': 1},
# "Sat_CD_CD_EA.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_EA.png', 'lat': 15, 'long': -75, 'width': 1},
# "Sat_CD_CD_EB.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_EB.png', 'lat': 15, 'long': -74, 'width': 1},
# "Sat_CD_CD_EC.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_EC.png', 'lat': 15, 'long': -73, 'width': 1},
# "Sat_CD_CD_ED.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_ED.png', 'lat': 15, 'long': -72, 'width': 1},
# "Sat_CD_CD_EE.png": {'localpath': 'Lvl2_1x1/CD_CD/', 'filename': 'Sat_CD_CD_EE.png', 'lat': 15, 'long': -71, 'width': 1},
# "Sat_CD_CE_AA.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_AA.png', 'lat': 19, 'long': -70, 'width': 1},
# "Sat_CD_CE_AB.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_AB.png', 'lat': 19, 'long': -69, 'width': 1},
# "Sat_CD_CE_AC.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_AC.png', 'lat': 19, 'long': -68, 'width': 1},
# "Sat_CD_CE_AD.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_AD.png', 'lat': 19, 'long': -67, 'width': 1},
# "Sat_CD_CE_AE.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_AE.png', 'lat': 19, 'long': -66, 'width': 1},
# "Sat_CD_CE_BA.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_BA.png', 'lat': 18, 'long': -70, 'width': 1},
# "Sat_CD_CE_BB.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_BB.png', 'lat': 18, 'long': -69, 'width': 1},
# "Sat_CD_CE_BC.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_BC.png', 'lat': 18, 'long': -68, 'width': 1},
# "Sat_CD_CE_BD.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_BD.png', 'lat': 18, 'long': -67, 'width': 1},
# "Sat_CD_CE_BE.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_BE.png', 'lat': 18, 'long': -66, 'width': 1},
# "Sat_CD_CE_CA.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_CA.png', 'lat': 17, 'long': -70, 'width': 1},
# "Sat_CD_CE_CB.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_CB.png', 'lat': 17, 'long': -69, 'width': 1},
# "Sat_CD_CE_CC.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_CC.png', 'lat': 17, 'long': -68, 'width': 1},
# "Sat_CD_CE_CD.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_CD.png', 'lat': 17, 'long': -67, 'width': 1},
# "Sat_CD_CE_CE.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_CE.png', 'lat': 17, 'long': -66, 'width': 1},
# "Sat_CD_CE_DA.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_DA.png', 'lat': 16, 'long': -70, 'width': 1},
# "Sat_CD_CE_DB.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_DB.png', 'lat': 16, 'long': -69, 'width': 1},
# "Sat_CD_CE_DC.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_DC.png', 'lat': 16, 'long': -68, 'width': 1},
# "Sat_CD_CE_DD.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_DD.png', 'lat': 16, 'long': -67, 'width': 1},
# "Sat_CD_CE_DE.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_DE.png', 'lat': 16, 'long': -66, 'width': 1},
# "Sat_CD_CE_EA.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_EA.png', 'lat': 15, 'long': -70, 'width': 1},
# "Sat_CD_CE_EB.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_EB.png', 'lat': 15, 'long': -69, 'width': 1},
# "Sat_CD_CE_EC.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_EC.png', 'lat': 15, 'long': -68, 'width': 1},
# "Sat_CD_CE_ED.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_ED.png', 'lat': 15, 'long': -67, 'width': 1},
# "Sat_CD_CE_EE.png": {'localpath': 'Lvl2_1x1/CD_CE/', 'filename': 'Sat_CD_CE_EE.png', 'lat': 15, 'long': -66, 'width': 1},
# "Sat_CD_CF_AA.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_AA.png', 'lat': 19, 'long': -65, 'width': 1},
# "Sat_CD_CF_AB.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_AB.png', 'lat': 19, 'long': -64, 'width': 1},
# "Sat_CD_CF_AC.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_AC.png', 'lat': 19, 'long': -63, 'width': 1},
# "Sat_CD_CF_AD.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_AD.png', 'lat': 19, 'long': -62, 'width': 1},
# "Sat_CD_CF_AE.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_AE.png', 'lat': 19, 'long': -61, 'width': 1},
# "Sat_CD_CF_BA.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_BA.png', 'lat': 18, 'long': -65, 'width': 1},
# "Sat_CD_CF_BB.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_BB.png', 'lat': 18, 'long': -64, 'width': 1},
# "Sat_CD_CF_BC.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_BC.png', 'lat': 18, 'long': -63, 'width': 1},
# "Sat_CD_CF_BD.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_BD.png', 'lat': 18, 'long': -62, 'width': 1},
# "Sat_CD_CF_BE.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_BE.png', 'lat': 18, 'long': -61, 'width': 1},
# "Sat_CD_CF_CA.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_CA.png', 'lat': 17, 'long': -65, 'width': 1},
# "Sat_CD_CF_CB.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_CB.png', 'lat': 17, 'long': -64, 'width': 1},
# "Sat_CD_CF_CC.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_CC.png', 'lat': 17, 'long': -63, 'width': 1},
# "Sat_CD_CF_CD.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_CD.png', 'lat': 17, 'long': -62, 'width': 1},
# "Sat_CD_CF_CE.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_CE.png', 'lat': 17, 'long': -61, 'width': 1},
# "Sat_CD_CF_DA.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_DA.png', 'lat': 16, 'long': -65, 'width': 1},
# "Sat_CD_CF_DB.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_DB.png', 'lat': 16, 'long': -64, 'width': 1},
# "Sat_CD_CF_DC.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_DC.png', 'lat': 16, 'long': -63, 'width': 1},
# "Sat_CD_CF_DD.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_DD.png', 'lat': 16, 'long': -62, 'width': 1},
# "Sat_CD_CF_DE.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_DE.png', 'lat': 16, 'long': -61, 'width': 1},
# "Sat_CD_CF_EA.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_EA.png', 'lat': 15, 'long': -65, 'width': 1},
# "Sat_CD_CF_EB.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_EB.png', 'lat': 15, 'long': -64, 'width': 1},
# "Sat_CD_CF_EC.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_EC.png', 'lat': 15, 'long': -63, 'width': 1},
# "Sat_CD_CF_ED.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_ED.png', 'lat': 15, 'long': -62, 'width': 1},
# "Sat_CD_CF_EE.png": {'localpath': 'Lvl2_1x1/CD_CF/', 'filename': 'Sat_CD_CF_EE.png', 'lat': 15, 'long': -61, 'width': 1},
# "Sat_CD_DA_AA.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_AA.png', 'lat': 14, 'long': -90, 'width': 1},
# "Sat_CD_DA_AB.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_AB.png', 'lat': 14, 'long': -89, 'width': 1},
# "Sat_CD_DA_AC.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_AC.png', 'lat': 14, 'long': -88, 'width': 1},
# "Sat_CD_DA_AD.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_AD.png', 'lat': 14, 'long': -87, 'width': 1},
# "Sat_CD_DA_AE.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_AE.png', 'lat': 14, 'long': -86, 'width': 1},
# "Sat_CD_DA_BA.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_BA.png', 'lat': 13, 'long': -90, 'width': 1},
# "Sat_CD_DA_BB.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_BB.png', 'lat': 13, 'long': -89, 'width': 1},
# "Sat_CD_DA_BC.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_BC.png', 'lat': 13, 'long': -88, 'width': 1},
# "Sat_CD_DA_BD.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_BD.png', 'lat': 13, 'long': -87, 'width': 1},
# "Sat_CD_DA_BE.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_BE.png', 'lat': 13, 'long': -86, 'width': 1},
# "Sat_CD_DA_CA.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_CA.png', 'lat': 12, 'long': -90, 'width': 1},
# "Sat_CD_DA_CB.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_CB.png', 'lat': 12, 'long': -89, 'width': 1},
# "Sat_CD_DA_CC.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_CC.png', 'lat': 12, 'long': -88, 'width': 1},
# "Sat_CD_DA_CD.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_CD.png', 'lat': 12, 'long': -87, 'width': 1},
# "Sat_CD_DA_CE.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_CE.png', 'lat': 12, 'long': -86, 'width': 1},
# "Sat_CD_DA_DA.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_DA.png', 'lat': 11, 'long': -90, 'width': 1},
# "Sat_CD_DA_DB.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_DB.png', 'lat': 11, 'long': -89, 'width': 1},
# "Sat_CD_DA_DC.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_DC.png', 'lat': 11, 'long': -88, 'width': 1},
# "Sat_CD_DA_DD.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_DD.png', 'lat': 11, 'long': -87, 'width': 1},
# "Sat_CD_DA_DE.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_DE.png', 'lat': 11, 'long': -86, 'width': 1},
# "Sat_CD_DA_EA.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_EA.png', 'lat': 10, 'long': -90, 'width': 1},
# "Sat_CD_DA_EB.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_EB.png', 'lat': 10, 'long': -89, 'width': 1},
# "Sat_CD_DA_EC.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_EC.png', 'lat': 10, 'long': -88, 'width': 1},
# "Sat_CD_DA_ED.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_ED.png', 'lat': 10, 'long': -87, 'width': 1},
# "Sat_CD_DA_EE.png": {'localpath': 'Lvl2_1x1/CD_DA/', 'filename': 'Sat_CD_DA_EE.png', 'lat': 10, 'long': -86, 'width': 1},
# "Sat_CD_DB_AA.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_AA.png', 'lat': 14, 'long': -85, 'width': 1},
# "Sat_CD_DB_AB.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_AB.png', 'lat': 14, 'long': -84, 'width': 1},
# "Sat_CD_DB_AC.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_AC.png', 'lat': 14, 'long': -83, 'width': 1},
# "Sat_CD_DB_AD.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_AD.png', 'lat': 14, 'long': -82, 'width': 1},
# "Sat_CD_DB_AE.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_AE.png', 'lat': 14, 'long': -81, 'width': 1},
# "Sat_CD_DB_BA.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_BA.png', 'lat': 13, 'long': -85, 'width': 1},
# "Sat_CD_DB_BB.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_BB.png', 'lat': 13, 'long': -84, 'width': 1},
# "Sat_CD_DB_BC.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_BC.png', 'lat': 13, 'long': -83, 'width': 1},
# "Sat_CD_DB_BD.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_BD.png', 'lat': 13, 'long': -82, 'width': 1},
# "Sat_CD_DB_BE.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_BE.png', 'lat': 13, 'long': -81, 'width': 1},
# "Sat_CD_DB_CA.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_CA.png', 'lat': 12, 'long': -85, 'width': 1},
# "Sat_CD_DB_CB.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_CB.png', 'lat': 12, 'long': -84, 'width': 1},
# "Sat_CD_DB_CC.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_CC.png', 'lat': 12, 'long': -83, 'width': 1},
# "Sat_CD_DB_CD.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_CD.png', 'lat': 12, 'long': -82, 'width': 1},
# "Sat_CD_DB_CE.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_CE.png', 'lat': 12, 'long': -81, 'width': 1},
# "Sat_CD_DB_DA.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_DA.png', 'lat': 11, 'long': -85, 'width': 1},
# "Sat_CD_DB_DB.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_DB.png', 'lat': 11, 'long': -84, 'width': 1},
# "Sat_CD_DB_DC.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_DC.png', 'lat': 11, 'long': -83, 'width': 1},
# "Sat_CD_DB_DD.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_DD.png', 'lat': 11, 'long': -82, 'width': 1},
# "Sat_CD_DB_DE.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_DE.png', 'lat': 11, 'long': -81, 'width': 1},
# "Sat_CD_DB_EA.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_EA.png', 'lat': 10, 'long': -85, 'width': 1},
# "Sat_CD_DB_EB.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_EB.png', 'lat': 10, 'long': -84, 'width': 1},
# "Sat_CD_DB_EC.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_EC.png', 'lat': 10, 'long': -83, 'width': 1},
# "Sat_CD_DB_ED.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_ED.png', 'lat': 10, 'long': -82, 'width': 1},
# "Sat_CD_DB_EE.png": {'localpath': 'Lvl2_1x1/CD_DB/', 'filename': 'Sat_CD_DB_EE.png', 'lat': 10, 'long': -81, 'width': 1},
# "Sat_CD_DC_AA.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_AA.png', 'lat': 14, 'long': -80, 'width': 1},
# "Sat_CD_DC_AB.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_AB.png', 'lat': 14, 'long': -79, 'width': 1},
# "Sat_CD_DC_AC.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_AC.png', 'lat': 14, 'long': -78, 'width': 1},
# "Sat_CD_DC_AD.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_AD.png', 'lat': 14, 'long': -77, 'width': 1},
# "Sat_CD_DC_AE.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_AE.png', 'lat': 14, 'long': -76, 'width': 1},
# "Sat_CD_DC_BA.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_BA.png', 'lat': 13, 'long': -80, 'width': 1},
# "Sat_CD_DC_BB.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_BB.png', 'lat': 13, 'long': -79, 'width': 1},
# "Sat_CD_DC_BC.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_BC.png', 'lat': 13, 'long': -78, 'width': 1},
# "Sat_CD_DC_BD.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_BD.png', 'lat': 13, 'long': -77, 'width': 1},
# "Sat_CD_DC_BE.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_BE.png', 'lat': 13, 'long': -76, 'width': 1},
# "Sat_CD_DC_CA.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_CA.png', 'lat': 12, 'long': -80, 'width': 1},
# "Sat_CD_DC_CB.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_CB.png', 'lat': 12, 'long': -79, 'width': 1},
# "Sat_CD_DC_CC.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_CC.png', 'lat': 12, 'long': -78, 'width': 1},
# "Sat_CD_DC_CD.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_CD.png', 'lat': 12, 'long': -77, 'width': 1},
# "Sat_CD_DC_CE.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_CE.png', 'lat': 12, 'long': -76, 'width': 1},
# "Sat_CD_DC_DA.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_DA.png', 'lat': 11, 'long': -80, 'width': 1},
# "Sat_CD_DC_DB.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_DB.png', 'lat': 11, 'long': -79, 'width': 1},
# "Sat_CD_DC_DC.png": {'localpath': 'Lvl2_1x1/CD_DC/', 'filename': 'Sat_CD_DC_DC.png', 'lat': 11, 'long': -78, 'width': 1},
# ...
# "Sat_CD_EE_DD.png": {'localpath': 'Lvl2_1x1/CD_EE/', 'filename': 'Sat_CD_EE_DD.png', 'lat': 6, 'long': -67, 'width': 1},
# "Sat_CD_EE_DE.png": {'localpath': 'Lvl2_1x1/CD_EE/', 'filename': 'Sat_CD_EE_DE.png', 'lat': 6, 'long': -66, 'width': 1},
# "Sat_CD_EE_EA.png": {'localpath': 'Lvl2_1x1/CD_EE/', 'filename': 'Sat_CD_EE_EA.png', 'lat': 5, 'long': -70, 'width': 1},
# "Sat_CD_EE_EB.png": {'localpath': 'Lvl2_1x1/CD_EE/', 'filename': 'Sat_CD_EE_EB.png', 'lat': 5, 'long': -69, 'width': 1},
# "Sat_CD_EE_EC.png": {'localpath': 'Lvl2_1x1/CD_EE/', 'filename': 'Sat_CD_EE_EC.png', 'lat': 5, 'long': -68, 'width': 1},
# "Sat_CD_EE_ED.png": {'localpath': 'Lvl2_1x1/CD_EE/', 'filename': 'Sat_CD_EE_ED.png', 'lat': 5, 'long': -67, 'width': 1},
# "Sat_CD_EE_EE.png": {'localpath': 'Lvl2_1x1/CD_EE/', 'filename': 'Sat_CD_EE_EE.png', 'lat': 5, 'long': -66, 'width': 1},
# "Sat_CD_EF_AA.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_AA.png', 'lat': 9, 'long': -65, 'width': 1},
# "Sat_CD_EF_AB.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_AB.png', 'lat': 9, 'long': -64, 'width': 1},
# "Sat_CD_EF_AC.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_AC.png', 'lat': 9, 'long': -63, 'width': 1},
# "Sat_CD_EF_AD.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_AD.png', 'lat': 9, 'long': -62, 'width': 1},
# "Sat_CD_EF_AE.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_AE.png', 'lat': 9, 'long': -61, 'width': 1},
# "Sat_CD_EF_BA.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_BA.png', 'lat': 8, 'long': -65, 'width': 1},
# "Sat_CD_EF_BB.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_BB.png', 'lat': 8, 'long': -64, 'width': 1},
# "Sat_CD_EF_BC.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_BC.png', 'lat': 8, 'long': -63, 'width': 1},
# "Sat_CD_EF_BD.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_BD.png', 'lat': 8, 'long': -62, 'width': 1},
# "Sat_CD_EF_BE.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_BE.png', 'lat': 8, 'long': -61, 'width': 1},
# "Sat_CD_EF_CA.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_CA.png', 'lat': 7, 'long': -65, 'width': 1},
# "Sat_CD_EF_CB.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_CB.png', 'lat': 7, 'long': -64, 'width': 1},
# "Sat_CD_EF_CC.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_CC.png', 'lat': 7, 'long': -63, 'width': 1},
# "Sat_CD_EF_CD.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_CD.png', 'lat': 7, 'long': -62, 'width': 1},
# "Sat_CD_EF_CE.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_CE.png', 'lat': 7, 'long': -61, 'width': 1},
# "Sat_CD_EF_DA.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_DA.png', 'lat': 6, 'long': -65, 'width': 1},
# "Sat_CD_EF_DB.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_DB.png', 'lat': 6, 'long': -64, 'width': 1},
# "Sat_CD_EF_DC.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_DC.png', 'lat': 6, 'long': -63, 'width': 1},
# "Sat_CD_EF_DD.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_DD.png', 'lat': 6, 'long': -62, 'width': 1},
# "Sat_CD_EF_DE.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_DE.png', 'lat': 6, 'long': -61, 'width': 1},
# "Sat_CD_EF_EA.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_EA.png', 'lat': 5, 'long': -65, 'width': 1},
# "Sat_CD_EF_EB.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_EB.png', 'lat': 5, 'long': -64, 'width': 1},
# "Sat_CD_EF_EC.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_EC.png', 'lat': 5, 'long': -63, 'width': 1},
# "Sat_CD_EF_ED.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_ED.png', 'lat': 5, 'long': -62, 'width': 1},
# "Sat_CD_EF_EE.png": {'localpath': 'Lvl2_1x1/CD_EF/', 'filename': 'Sat_CD_EF_EE.png', 'lat': 5, 'long': -61, 'width': 1},
# "Sat_CD_FC_AA.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_AA.png', 'lat': 4, 'long': -80, 'width': 1},
# "Sat_CD_FC_AB.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_AB.png', 'lat': 4, 'long': -79, 'width': 1},
# "Sat_CD_FC_AC.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_AC.png', 'lat': 4, 'long': -78, 'width': 1},
# "Sat_CD_FC_AD.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_AD.png', 'lat': 4, 'long': -77, 'width': 1},
# "Sat_CD_FC_AE.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_AE.png', 'lat': 4, 'long': -76, 'width': 1},
# "Sat_CD_FC_BA.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_BA.png', 'lat': 3, 'long': -80, 'width': 1},
# "Sat_CD_FC_BB.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_BB.png', 'lat': 3, 'long': -79, 'width': 1},
# "Sat_CD_FC_BC.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_BC.png', 'lat': 3, 'long': -78, 'width': 1},
# "Sat_CD_FC_BD.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_BD.png', 'lat': 3, 'long': -77, 'width': 1},
# "Sat_CD_FC_BE.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_BE.png', 'lat': 3, 'long': -76, 'width': 1},
# "Sat_CD_FC_CA.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_CA.png', 'lat': 2, 'long': -80, 'width': 1},
# "Sat_CD_FC_CB.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_CB.png', 'lat': 2, 'long': -79, 'width': 1},
# "Sat_CD_FC_CC.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_CC.png', 'lat': 2, 'long': -78, 'width': 1},
# "Sat_CD_FC_CD.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_CD.png', 'lat': 2, 'long': -77, 'width': 1},
# "Sat_CD_FC_CE.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_CE.png', 'lat': 2, 'long': -76, 'width': 1},
# "Sat_CD_FC_DA.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_DA.png', 'lat': 1, 'long': -80, 'width': 1},
# "Sat_CD_FC_DB.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_DB.png', 'lat': 1, 'long': -79, 'width': 1},
# "Sat_CD_FC_DC.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_DC.png', 'lat': 1, 'long': -78, 'width': 1},
# "Sat_CD_FC_DD.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_DD.png', 'lat': 1, 'long': -77, 'width': 1},
# "Sat_CD_FC_DE.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_DE.png', 'lat': 1, 'long': -76, 'width': 1},
# "Sat_CD_FC_EA.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_EA.png', 'lat': 0, 'long': -80, 'width': 1},
# "Sat_CD_FC_EB.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_EB.png', 'lat': 0, 'long': -79, 'width': 1},
# "Sat_CD_FC_EC.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_EC.png', 'lat': 0, 'long': -78, 'width': 1},
# "Sat_CD_FC_ED.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_ED.png', 'lat': 0, 'long': -77, 'width': 1},
# "Sat_CD_FC_EE.png": {'localpath': 'Lvl2_1x1/CD_FC/', 'filename': 'Sat_CD_FC_EE.png', 'lat': 0, 'long': -76, 'width': 1},
# "Sat_CD_FD_AA.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_AA.png', 'lat': 4, 'long': -75, 'width': 1},
# "Sat_CD_FD_AB.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_AB.png', 'lat': 4, 'long': -74, 'width': 1},
# "Sat_CD_FD_AC.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_AC.png', 'lat': 4, 'long': -73, 'width': 1},
# "Sat_CD_FD_AD.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_AD.png', 'lat': 4, 'long': -72, 'width': 1},
# "Sat_CD_FD_AE.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_AE.png', 'lat': 4, 'long': -71, 'width': 1},
# "Sat_CD_FD_BA.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_BA.png', 'lat': 3, 'long': -75, 'width': 1},
# "Sat_CD_FD_BB.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_BB.png', 'lat': 3, 'long': -74, 'width': 1},
# "Sat_CD_FD_BC.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_BC.png', 'lat': 3, 'long': -73, 'width': 1},
# "Sat_CD_FD_BD.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_BD.png', 'lat': 3, 'long': -72, 'width': 1},
# "Sat_CD_FD_BE.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_BE.png', 'lat': 3, 'long': -71, 'width': 1},
# "Sat_CD_FD_CA.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_CA.png', 'lat': 2, 'long': -75, 'width': 1},
# "Sat_CD_FD_CB.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_CB.png', 'lat': 2, 'long': -74, 'width': 1},
# "Sat_CD_FD_CC.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_CC.png', 'lat': 2, 'long': -73, 'width': 1},
# "Sat_CD_FD_CD.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_CD.png', 'lat': 2, 'long': -72, 'width': 1},
# "Sat_CD_FD_CE.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_CE.png', 'lat': 2, 'long': -71, 'width': 1},
# "Sat_CD_FD_DA.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_DA.png', 'lat': 1, 'long': -75, 'width': 1},
# "Sat_CD_FD_DB.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_DB.png', 'lat': 1, 'long': -74, 'width': 1},
# "Sat_CD_FD_DC.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_DC.png', 'lat': 1, 'long': -73, 'width': 1},
# "Sat_CD_FD_DD.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_DD.png', 'lat': 1, 'long': -72, 'width': 1},
# "Sat_CD_FD_DE.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_DE.png', 'lat': 1, 'long': -71, 'width': 1},
# "Sat_CD_FD_EA.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_EA.png', 'lat': 0, 'long': -75, 'width': 1},
# "Sat_CD_FD_EB.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_EB.png', 'lat': 0, 'long': -74, 'width': 1},
# "Sat_CD_FD_EC.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_EC.png', 'lat': 0, 'long': -73, 'width': 1},
# "Sat_CD_FD_ED.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_ED.png', 'lat': 0, 'long': -72, 'width': 1},
# "Sat_CD_FD_EE.png": {'localpath': 'Lvl2_1x1/CD_FD/', 'filename': 'Sat_CD_FD_EE.png', 'lat': 0, 'long': -71, 'width': 1},
# "Sat_CD_FE_AA.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_AA.png', 'lat': 4, 'long': -70, 'width': 1},
# "Sat_CD_FE_AB.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_AB.png', 'lat': 4, 'long': -69, 'width': 1},
# "Sat_CD_FE_AC.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_AC.png', 'lat': 4, 'long': -68, 'width': 1},
# "Sat_CD_FE_AD.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_AD.png', 'lat': 4, 'long': -67, 'width': 1},
# "Sat_CD_FE_AE.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_AE.png', 'lat': 4, 'long': -66, 'width': 1},
# "Sat_CD_FE_BA.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_BA.png', 'lat': 3, 'long': -70, 'width': 1},
# "Sat_CD_FE_BB.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_BB.png', 'lat': 3, 'long': -69, 'width': 1},
# "Sat_CD_FE_BC.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_BC.png', 'lat': 3, 'long': -68, 'width': 1},
# "Sat_CD_FE_BD.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_BD.png', 'lat': 3, 'long': -67, 'width': 1},
# "Sat_CD_FE_BE.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_BE.png', 'lat': 3, 'long': -66, 'width': 1},
# "Sat_CD_FE_CA.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_CA.png', 'lat': 2, 'long': -70, 'width': 1},
# "Sat_CD_FE_CB.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_CB.png', 'lat': 2, 'long': -69, 'width': 1},
# "Sat_CD_FE_CC.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_CC.png', 'lat': 2, 'long': -68, 'width': 1},
# "Sat_CD_FE_CD.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_CD.png', 'lat': 2, 'long': -67, 'width': 1},
# "Sat_CD_FE_CE.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_CE.png', 'lat': 2, 'long': -66, 'width': 1},
# "Sat_CD_FE_DA.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_DA.png', 'lat': 1, 'long': -70, 'width': 1},
# "Sat_CD_FE_DB.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_DB.png', 'lat': 1, 'long': -69, 'width': 1},
# "Sat_CD_FE_DC.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_DC.png', 'lat': 1, 'long': -68, 'width': 1},
# "Sat_CD_FE_DD.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_DD.png', 'lat': 1, 'long': -67, 'width': 1},
# "Sat_CD_FE_DE.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_DE.png', 'lat': 1, 'long': -66, 'width': 1},
# "Sat_CD_FE_EA.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_EA.png', 'lat': 0, 'long': -70, 'width': 1},
# "Sat_CD_FE_EB.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_EB.png', 'lat': 0, 'long': -69, 'width': 1},
# "Sat_CD_FE_EC.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_EC.png', 'lat': 0, 'long': -68, 'width': 1},
# "Sat_CD_FE_ED.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_ED.png', 'lat': 0, 'long': -67, 'width': 1},
# "Sat_CD_FE_EE.png": {'localpath': 'Lvl2_1x1/CD_FE/', 'filename': 'Sat_CD_FE_EE.png', 'lat': 0, 'long': -66, 'width': 1},
# "Sat_CD_FF_AA.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_AA.png', 'lat': 4, 'long': -65, 'width': 1},
# "Sat_CD_FF_AB.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_AB.png', 'lat': 4, 'long': -64, 'width': 1},
# "Sat_CD_FF_AC.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_AC.png', 'lat': 4, 'long': -63, 'width': 1},
# "Sat_CD_FF_AD.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_AD.png', 'lat': 4, 'long': -62, 'width': 1},
# "Sat_CD_FF_AE.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_AE.png', 'lat': 4, 'long': -61, 'width': 1},
# "Sat_CD_FF_BA.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_BA.png', 'lat': 3, 'long': -65, 'width': 1},
# "Sat_CD_FF_BB.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_BB.png', 'lat': 3, 'long': -64, 'width': 1},
# "Sat_CD_FF_BC.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_BC.png', 'lat': 3, 'long': -63, 'width': 1},
# "Sat_CD_FF_BD.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_BD.png', 'lat': 3, 'long': -62, 'width': 1},
# "Sat_CD_FF_BE.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_BE.png', 'lat': 3, 'long': -61, 'width': 1},
# "Sat_CD_FF_CA.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_CA.png', 'lat': 2, 'long': -65, 'width': 1},
# "Sat_CD_FF_CB.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_CB.png', 'lat': 2, 'long': -64, 'width': 1},
# "Sat_CD_FF_CC.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_CC.png', 'lat': 2, 'long': -63, 'width': 1},
# "Sat_CD_FF_CD.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_CD.png', 'lat': 2, 'long': -62, 'width': 1},
# "Sat_CD_FF_CE.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_CE.png', 'lat': 2, 'long': -61, 'width': 1},
# "Sat_CD_FF_DA.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_DA.png', 'lat': 1, 'long': -65, 'width': 1},
# "Sat_CD_FF_DB.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_DB.png', 'lat': 1, 'long': -64, 'width': 1},
# "Sat_CD_FF_DC.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_DC.png', 'lat': 1, 'long': -63, 'width': 1},
# "Sat_CD_FF_DD.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_DD.png', 'lat': 1, 'long': -62, 'width': 1},
# "Sat_CD_FF_DE.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_DE.png', 'lat': 1, 'long': -61, 'width': 1},
# "Sat_CD_FF_EA.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_EA.png', 'lat': 0, 'long': -65, 'width': 1},
# "Sat_CD_FF_EB.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_EB.png', 'lat': 0, 'long': -64, 'width': 1},
# "Sat_CD_FF_EC.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_EC.png', 'lat': 0, 'long': -63, 'width': 1},
# "Sat_CD_FF_ED.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_ED.png', 'lat': 0, 'long': -62, 'width': 1},
# "Sat_CD_FF_EE.png": {'localpath': 'Lvl2_1x1/CD_FF/', 'filename': 'Sat_CD_FF_EE.png', 'lat': 0, 'long': -61, 'width': 1},

# %%
# Hamburg - Sub 1Deg - BH_BB_BE / BG_BC_BA

BG_BB_BD_Sub1Deg = create_sub1deg_dictionary("Lvl3_0p2x0p2/BG_BB_BD/", "Sat_BG_BB_BD_",  53,  8)
BG_BB_BE_Sub1Deg = create_sub1deg_dictionary("Lvl3_0p2x0p2/BG_BB_BE/", "Sat_BG_BB_BE_",  53,  9)
BG_BC_BA_Sub1Deg = create_sub1deg_dictionary("Lvl3_0p2x0p2/BG_BC_BA/", "Sat_BG_BC_BA_",  53, 10)

Hamburg_Sub1Degs_List = [
    BG_BB_BD_Sub1Deg,
    BG_BB_BE_Sub1Deg,
    BG_BC_BA_Sub1Deg,
]

# Loop through the dictionaries, and then fields
for dictionary in Hamburg_Sub1Degs_List:
    for key, value in dictionary.items():
        print(f"\"{key}\": {value},")
# Out:
# "Sat_BG_BB_BD_AA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_AA.png', 'lat': 53.8, 'long': 8.0, 'width': 0.2},
# "Sat_BG_BB_BD_AB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_AB.png', 'lat': 53.8, 'long': 8.2, 'width': 0.2},
# "Sat_BG_BB_BD_AC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_AC.png', 'lat': 53.8, 'long': 8.4, 'width': 0.2},
# "Sat_BG_BB_BD_AD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_AD.png', 'lat': 53.8, 'long': 8.6, 'width': 0.2},
# "Sat_BG_BB_BD_AE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_AE.png', 'lat': 53.8, 'long': 8.8, 'width': 0.2},
# "Sat_BG_BB_BD_BA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_BA.png', 'lat': 53.6, 'long': 8.0, 'width': 0.2},
# "Sat_BG_BB_BD_BB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_BB.png', 'lat': 53.6, 'long': 8.2, 'width': 0.2},
# "Sat_BG_BB_BD_BC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_BC.png', 'lat': 53.6, 'long': 8.4, 'width': 0.2},
# "Sat_BG_BB_BD_BD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_BD.png', 'lat': 53.6, 'long': 8.6, 'width': 0.2},
# "Sat_BG_BB_BD_BE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_BE.png', 'lat': 53.6, 'long': 8.8, 'width': 0.2},
# "Sat_BG_BB_BD_CA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_CA.png', 'lat': 53.4, 'long': 8.0, 'width': 0.2},
# "Sat_BG_BB_BD_CB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_CB.png', 'lat': 53.4, 'long': 8.2, 'width': 0.2},
# "Sat_BG_BB_BD_CC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_CC.png', 'lat': 53.4, 'long': 8.4, 'width': 0.2},
# "Sat_BG_BB_BD_CD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_CD.png', 'lat': 53.4, 'long': 8.6, 'width': 0.2},
# "Sat_BG_BB_BD_CE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_CE.png', 'lat': 53.4, 'long': 8.8, 'width': 0.2},
# "Sat_BG_BB_BD_DA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_DA.png', 'lat': 53.2, 'long': 8.0, 'width': 0.2},
# "Sat_BG_BB_BD_DB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_DB.png', 'lat': 53.2, 'long': 8.2, 'width': 0.2},
# "Sat_BG_BB_BD_DC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_DC.png', 'lat': 53.2, 'long': 8.4, 'width': 0.2},
# "Sat_BG_BB_BD_DD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_DD.png', 'lat': 53.2, 'long': 8.6, 'width': 0.2},
# "Sat_BG_BB_BD_DE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_DE.png', 'lat': 53.2, 'long': 8.8, 'width': 0.2},
# "Sat_BG_BB_BD_EA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_EA.png', 'lat': 53.0, 'long': 8.0, 'width': 0.2},
# "Sat_BG_BB_BD_EB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_EB.png', 'lat': 53.0, 'long': 8.2, 'width': 0.2},
# "Sat_BG_BB_BD_EC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_EC.png', 'lat': 53.0, 'long': 8.4, 'width': 0.2},
# "Sat_BG_BB_BD_ED.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_ED.png', 'lat': 53.0, 'long': 8.6, 'width': 0.2},
# "Sat_BG_BB_BD_EE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BD/', 'filename': 'Sat_BG_BB_BD_EE.png', 'lat': 53.0, 'long': 8.8, 'width': 0.2},
# "Sat_BG_BB_BE_AA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_AA.png', 'lat': 53.8, 'long': 9.0, 'width': 0.2},
# "Sat_BG_BB_BE_AB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_AB.png', 'lat': 53.8, 'long': 9.2, 'width': 0.2},
# "Sat_BG_BB_BE_AC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_AC.png', 'lat': 53.8, 'long': 9.4, 'width': 0.2},
# "Sat_BG_BB_BE_AD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_AD.png', 'lat': 53.8, 'long': 9.6, 'width': 0.2},
# "Sat_BG_BB_BE_AE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_AE.png', 'lat': 53.8, 'long': 9.8, 'width': 0.2},
# "Sat_BG_BB_BE_BA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_BA.png', 'lat': 53.6, 'long': 9.0, 'width': 0.2},
# "Sat_BG_BB_BE_BB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_BB.png', 'lat': 53.6, 'long': 9.2, 'width': 0.2},
# "Sat_BG_BB_BE_BC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_BC.png', 'lat': 53.6, 'long': 9.4, 'width': 0.2},
# "Sat_BG_BB_BE_BD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_BD.png', 'lat': 53.6, 'long': 9.6, 'width': 0.2},
# "Sat_BG_BB_BE_BE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_BE.png', 'lat': 53.6, 'long': 9.8, 'width': 0.2},
# "Sat_BG_BB_BE_CA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_CA.png', 'lat': 53.4, 'long': 9.0, 'width': 0.2},
# "Sat_BG_BB_BE_CB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_CB.png', 'lat': 53.4, 'long': 9.2, 'width': 0.2},
# "Sat_BG_BB_BE_CC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_CC.png', 'lat': 53.4, 'long': 9.4, 'width': 0.2},
# "Sat_BG_BB_BE_CD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_CD.png', 'lat': 53.4, 'long': 9.6, 'width': 0.2},
# "Sat_BG_BB_BE_CE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_CE.png', 'lat': 53.4, 'long': 9.8, 'width': 0.2},
# "Sat_BG_BB_BE_DA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_DA.png', 'lat': 53.2, 'long': 9.0, 'width': 0.2},
# "Sat_BG_BB_BE_DB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_DB.png', 'lat': 53.2, 'long': 9.2, 'width': 0.2},
# "Sat_BG_BB_BE_DC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_DC.png', 'lat': 53.2, 'long': 9.4, 'width': 0.2},
# "Sat_BG_BB_BE_DD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_DD.png', 'lat': 53.2, 'long': 9.6, 'width': 0.2},
# "Sat_BG_BB_BE_DE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_DE.png', 'lat': 53.2, 'long': 9.8, 'width': 0.2},
# "Sat_BG_BB_BE_EA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_EA.png', 'lat': 53.0, 'long': 9.0, 'width': 0.2},
# "Sat_BG_BB_BE_EB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_EB.png', 'lat': 53.0, 'long': 9.2, 'width': 0.2},
# "Sat_BG_BB_BE_EC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_EC.png', 'lat': 53.0, 'long': 9.4, 'width': 0.2},
# "Sat_BG_BB_BE_ED.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_ED.png', 'lat': 53.0, 'long': 9.6, 'width': 0.2},
# "Sat_BG_BB_BE_EE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BB_BE/', 'filename': 'Sat_BG_BB_BE_EE.png', 'lat': 53.0, 'long': 9.8, 'width': 0.2},
# "Sat_BG_BC_BA_AA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_AA.png', 'lat': 53.8, 'long': 10.0, 'width': 0.2},
# "Sat_BG_BC_BA_AB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_AB.png', 'lat': 53.8, 'long': 10.2, 'width': 0.2},
# "Sat_BG_BC_BA_AC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_AC.png', 'lat': 53.8, 'long': 10.4, 'width': 0.2},
# "Sat_BG_BC_BA_AD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_AD.png', 'lat': 53.8, 'long': 10.6, 'width': 0.2},
# "Sat_BG_BC_BA_AE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_AE.png', 'lat': 53.8, 'long': 10.8, 'width': 0.2},
# "Sat_BG_BC_BA_BA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_BA.png', 'lat': 53.6, 'long': 10.0, 'width': 0.2},
# "Sat_BG_BC_BA_BB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_BB.png', 'lat': 53.6, 'long': 10.2, 'width': 0.2},
# "Sat_BG_BC_BA_BC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_BC.png', 'lat': 53.6, 'long': 10.4, 'width': 0.2},
# "Sat_BG_BC_BA_BD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_BD.png', 'lat': 53.6, 'long': 10.6, 'width': 0.2},
# "Sat_BG_BC_BA_BE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_BE.png', 'lat': 53.6, 'long': 10.8, 'width': 0.2},
# "Sat_BG_BC_BA_CA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_CA.png', 'lat': 53.4, 'long': 10.0, 'width': 0.2},
# "Sat_BG_BC_BA_CB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_CB.png', 'lat': 53.4, 'long': 10.2, 'width': 0.2},
# "Sat_BG_BC_BA_CC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_CC.png', 'lat': 53.4, 'long': 10.4, 'width': 0.2},
# "Sat_BG_BC_BA_CD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_CD.png', 'lat': 53.4, 'long': 10.6, 'width': 0.2},
# "Sat_BG_BC_BA_CE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_CE.png', 'lat': 53.4, 'long': 10.8, 'width': 0.2},
# "Sat_BG_BC_BA_DA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_DA.png', 'lat': 53.2, 'long': 10.0, 'width': 0.2},
# "Sat_BG_BC_BA_DB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_DB.png', 'lat': 53.2, 'long': 10.2, 'width': 0.2},
# "Sat_BG_BC_BA_DC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_DC.png', 'lat': 53.2, 'long': 10.4, 'width': 0.2},
# "Sat_BG_BC_BA_DD.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_DD.png', 'lat': 53.2, 'long': 10.6, 'width': 0.2},
# "Sat_BG_BC_BA_DE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_DE.png', 'lat': 53.2, 'long': 10.8, 'width': 0.2},
# "Sat_BG_BC_BA_EA.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_EA.png', 'lat': 53.0, 'long': 10.0, 'width': 0.2},
# "Sat_BG_BC_BA_EB.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_EB.png', 'lat': 53.0, 'long': 10.2, 'width': 0.2},
# "Sat_BG_BC_BA_EC.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_EC.png', 'lat': 53.0, 'long': 10.4, 'width': 0.2},
# "Sat_BG_BC_BA_ED.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_ED.png', 'lat': 53.0, 'long': 10.6, 'width': 0.2},
# "Sat_BG_BC_BA_EE.png": {'localpath': 'Lvl3_0p2x0p2/BG_BC_BA/', 'filename': 'Sat_BG_BC_BA_EE.png', 'lat': 53.0, 'long': 10.8, 'width': 0.2},

# %%
RootDir = "C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/"
ensure_dir(RootDir)

brightness = 35

oauth = SetupOAuth(client_id, client_secret)


# Loop over the data structure
for data in belgium_data_1Deg:

    TilesetDir = os.path.join(RootDir, data["localpath"])
    filepath   = os.path.join(TilesetDir, data["filename"])

    ensure_dir(TilesetDir)

    print(filepath)

    if not os.path.exists(filepath):

        print(f"Downloading and enhancing image: {data['filename']}")

        # Call your functions using the metadata
        download_GM(filepath, data["lat"], data["long"], data["width"])
        # change_absolute_brightness(filepath, filepath, brightness)
        #adjust_image_properties(filepath, filepath, brightness_delta=30, contrast_factor=1.5, saturation_factor=1.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       9 # Loop over the data structure
#      10 for data in belgium_data_1Deg:
# ---> 12     TilesetDir = os.path.join(RootDir, data["localpath"])
#      13     filepath   = os.path.join(TilesetDir, data["filename"])
#      15     ensure_dir(TilesetDir)
#
# TypeError: string indices must be integers, not 'str'

# %%
datestr = globalmosaic_dates["2024Q2"]

RootDir = r"C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/{datestr}/"
ensure_dir(RootDir)

oauth = SetupOAuth(client_id, client_secret)

# Loop over the data structure
for data in BG_CF_1Deg.values():
    TilesetDir = os.path.join(RootDir, data["localpath"])
    filepath   = os.path.join(TilesetDir, data["filename"])

    ensure_dir(TilesetDir)

    print(filepath)

    if not os.path.exists(filepath):

        print(f"Downloading and enhancing image: {data['filename']}")

        # Call your functions using the metadata
        download_GM2(filepath, data["lat"], data["long"], data["width"])
# Out:
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/{datestr}/Lvl2_1x1/BG_CF/Sat_BG_CF_AA.png
# Downloading and enhancing image: Sat_BG_CF_AA.png
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 22
#      19 print(f"Downloading and enhancing image: {data['filename']}")
#      21 # Call your functions using the metadata
# ---> 22 download_GM2(filepath, data["lat"], data["long"], data["width"])
#
# TypeError: download_GM2() missing 1 required positional argument: 'width'

# %%
RootDir = "C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/"
ensure_dir(RootDir)
brightness = 35

def process_tileset_dict(tileset_dict, datestr):

    oauth = SetupOAuth(client_id, client_secret)

    for data in tileset_dict.values():
        TilesetDir = os.path.join(root_dir, data["localpath"])
        filepath   = os.path.join(TilesetDir, data["filename"])

        ensure_dir(TilesetDir)

        print(filepath)

        if not os.path.exists(filepath):

            print(f"Downloading and enhancing image: {data['filename']}")

            # Call your functions using the metadata
            download_GM2(filepath, datestr, data["lat"], data["long"], data["width"])

# %%
# Loop over the dictionaries and call the download function for each

datestr = globalmosaic_dates["2024Q2"]

root_dir = f"C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/{datestr}/"
ensure_dir(root_dir)

for tileset_dict in Hamburg_Sub1Degs_List:
    process_tileset_dict(tileset_dict, datestr)
# Out:
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_AA.png
# Downloading and enhancing image: Sat_BG_BB_BD_AA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_AB.png
# Downloading and enhancing image: Sat_BG_BB_BD_AB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_AC.png
# Downloading and enhancing image: Sat_BG_BB_BD_AC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_AD.png
# Downloading and enhancing image: Sat_BG_BB_BD_AD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_AE.png
# Downloading and enhancing image: Sat_BG_BB_BD_AE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_BA.png
# Downloading and enhancing image: Sat_BG_BB_BD_BA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_BB.png
# Downloading and enhancing image: Sat_BG_BB_BD_BB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_BC.png
# Downloading and enhancing image: Sat_BG_BB_BD_BC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_BD.png
# Downloading and enhancing image: Sat_BG_BB_BD_BD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_BE.png
# Downloading and enhancing image: Sat_BG_BB_BD_BE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_CA.png
# Downloading and enhancing image: Sat_BG_BB_BD_CA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_CB.png
# Downloading and enhancing image: Sat_BG_BB_BD_CB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_CC.png
# Downloading and enhancing image: Sat_BG_BB_BD_CC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_CD.png
# Downloading and enhancing image: Sat_BG_BB_BD_CD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_CE.png
# Downloading and enhancing image: Sat_BG_BB_BD_CE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_DA.png
# Downloading and enhancing image: Sat_BG_BB_BD_DA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_DB.png
# Downloading and enhancing image: Sat_BG_BB_BD_DB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_DC.png
# Downloading and enhancing image: Sat_BG_BB_BD_DC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_DD.png
# Downloading and enhancing image: Sat_BG_BB_BD_DD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_DE.png
# Downloading and enhancing image: Sat_BG_BB_BD_DE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_EA.png
# Downloading and enhancing image: Sat_BG_BB_BD_EA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_EB.png
# Downloading and enhancing image: Sat_BG_BB_BD_EB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_EC.png
# Downloading and enhancing image: Sat_BG_BB_BD_EC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_ED.png
# Downloading and enhancing image: Sat_BG_BB_BD_ED.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BD/Sat_BG_BB_BD_EE.png
# Downloading and enhancing image: Sat_BG_BB_BD_EE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_AA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_AB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_AC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_AD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_AE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_BA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_BB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_BC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_BD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_BE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_CA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_CB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_CC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_CD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_CE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_DA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_DB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_DC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_DD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_DE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_EA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_EB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_EC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_ED.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BB_BE/Sat_BG_BB_BE_EE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_AA.png
# Downloading and enhancing image: Sat_BG_BC_BA_AA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_AB.png
# Downloading and enhancing image: Sat_BG_BC_BA_AB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_AC.png
# Downloading and enhancing image: Sat_BG_BC_BA_AC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_AD.png
# Downloading and enhancing image: Sat_BG_BC_BA_AD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_AE.png
# Downloading and enhancing image: Sat_BG_BC_BA_AE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_BA.png
# Downloading and enhancing image: Sat_BG_BC_BA_BA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_BB.png
# Downloading and enhancing image: Sat_BG_BC_BA_BB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_BC.png
# Downloading and enhancing image: Sat_BG_BC_BA_BC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_BD.png
# Downloading and enhancing image: Sat_BG_BC_BA_BD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_BE.png
# Downloading and enhancing image: Sat_BG_BC_BA_BE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_CA.png
# Downloading and enhancing image: Sat_BG_BC_BA_CA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_CB.png
# Downloading and enhancing image: Sat_BG_BC_BA_CB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_CC.png
# Downloading and enhancing image: Sat_BG_BC_BA_CC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_CD.png
# Downloading and enhancing image: Sat_BG_BC_BA_CD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_CE.png
# Downloading and enhancing image: Sat_BG_BC_BA_CE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_DA.png
# Downloading and enhancing image: Sat_BG_BC_BA_DA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_DB.png
# Downloading and enhancing image: Sat_BG_BC_BA_DB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_DC.png
# Downloading and enhancing image: Sat_BG_BC_BA_DC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_DD.png
# Downloading and enhancing image: Sat_BG_BC_BA_DD.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_DE.png
# Downloading and enhancing image: Sat_BG_BC_BA_DE.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_EA.png
# Downloading and enhancing image: Sat_BG_BC_BA_EA.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_EB.png
# Downloading and enhancing image: Sat_BG_BC_BA_EB.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_EC.png
# Downloading and enhancing image: Sat_BG_BC_BA_EC.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_ED.png
# Downloading and enhancing image: Sat_BG_BC_BA_ED.png
# C:/Util/GlobeLibrary_MapPrep/_WIP/exp/MapLib/2024-04-01/Lvl3_0p2x0p2/BG_BC_BA/Sat_BG_BC_BA_EE.png
# Downloading and enhancing image: Sat_BG_BC_BA_EE.png
